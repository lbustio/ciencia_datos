# %% [markdown]
# # Actividad 10: Estadística descriptiva con Python

# %% [markdown]
# ## Ejercicio de la clase

# %% [markdown]
# ### Ejercicio
#
# El RMS Titanic fue un famoso transatlántico británico que se hundió trágicamente en su viaje inaugural en la madrugada del 15 de abril de 1912. Conocido por su lujoso diseño y considerado como “insumergible”, el Titanic era considerado uno de los barcos más avanzados de su tiempo. Sin embargo, su colisión con un iceberg en el Atlántico Norte resultó en una de las mayores tragedias marítimas de la historia.
#
# El desafortunado naufragio del Titanic ha capturado la imaginación de muchas personas a lo largo de los años y ha generado un gran interés tanto en la historia como en el análisis de datos. Para entender mejor los eventos y las características de los pasajeros a bordo del Titanic, se ha creado un conjunto de datos llamado “titanic.csv”, que contiene información sobre los pasajeros y su destino durante el viaje.
#
# Este conjunto de datos del Titanic se ha convertido en una fuente popular para realizar ejercicios de ciencia de datos y análisis estadístico. Proporciona una oportunidad para explorar diferentes aspectos relacionados con los pasajeros, como sus características demográficas, las condiciones de viaje y los factores que podrían haber influido en su supervivencia.
#
# El ejercicio que se propone permite aplicar técnicas de estadística descriptiva y análisis de datos para obtener información sobre los pasajeros del Titanic y sus experiencias durante el trágico evento. Además, ofrece la oportunidad de desarrollar habilidades de programación y manipulación de datos, así como de presentar conclusiones respaldadas por evidencia estadística.
#
# ### Instrucciones
#
# En este ejercicio, se utilizará la estadística descriptiva para analizar el conjunto de datos “titanic.csv” y responder a varias preguntas relacionadas con los tipos de pasajeros, las cubiertas, el lugar de embarque, la composición familiar y los factores de supervivencia. El ejercicio está orientado a responder la siguiente pregunta:
#
# _Si yo fuera pasajero en el Titanic, ¿qué chance tendría de sobrevivir?_
#
# A continuación, se detallan las indicaciones para llevar a cabo el análisis teniendo en cuenta de que son instrucciones generales y no un “paso-a-paso” para solucionar el ejercicio:
#
# 1. Importación de datos:
# - Descarga el conjunto de datos del Titanic en formato CSV desde Brightspace y guárdalo como “titanic.csv”.
# - Importa los datos en un entorno de programación o software de tu elección, como Python con la biblioteca Pandas.
# 2. Exploración inicial de datos:
# - Utiliza la función de lectura de datos adecuada para importar el archivo “titanic.csv” y cargar los datos en una estructura de datos, como un DataFrame de Pandas.
# - Realiza una inspección inicial del conjunto de datos para familiarizarte con su estructura y contenido.
# - Muestra una vista previa de los primeros registros utilizando la función head() para comprender la información que se encuentra en cada columna.
# 3. Tipos de pasajeros:
# - Utiliza la estadística descriptiva para analizar las variables relevantes que describen los tipos de pasajeros, como “Age” (edad), “Sex” (género) y “Pclass” (clase).
# - Calcula medidas de resumen, como la media (mean()), la mediana (median()) y la moda (mode()), para cada una de estas variables.
# - Genera gráficos adecuados (como histogramas o diagramas de barras, utilizando la función plot() de Pandas entre otros) para visualizar la distribución de las variables y detectar posibles patrones.
# 4. Cubierta de los pasajeros:
# - Utiliza la información de la columna “Cabin” para extraer la cubierta de cada pasajero.
# - Analiza la relación entre la cubierta, la clase (“Pclass”) y el índice de supervivencia (“Survived”). ¿La ubicación en la cubierta de los pasajeros y su clase está relacionada con la supervivencia?
# - Calcula medidas de resumen, como el porcentaje de supervivencia por cubierta y por clase.
# - Genera gráficos adecuados (como diagramas de barras apilados o diagramas de dispersión entre otros) para visualizar estas relaciones.
# 5. Lugar de embarque de los pasajeros:
# - Analiza la columna “Embarked” para determinar el lugar de embarque de cada pasajero.
# - Utiliza la estadística descriptiva para determinar el lugar de embarque más común y su distribución en el conjunto de datos.
# - Genera gráficos adecuados (como diagramas de barras o gráficos circulares entre otros) para visualizar la distribución de los pasajeros por lugar de embarque.
# 6. Composición familiar y supervivencia:
# - Utiliza la información de las columnas “SibSp” (número de hermanos/cónyuges a bordo) y “Parch” (número de padres/hijos a bordo) para analizar la composición familiar de los pasajeros.
# - Analiza la relación entre la cantidad de personas que viajaban solas o con familia y su índice de supervivencia.
# - Calcula medidas de resumen, como el porcentaje de supervivencia para cada categoría de viaje (solo o con familia).
# - Genera gráficos adecuados (como diagramas de barras o gráficos de sectores entre otros) para visualizar estas relaciones.
# 7. Factores de supervivencia:
# - Utiliza las variables relevantes del conjunto de datos, como “Age” (edad), “Sex” (género), “Pclass” (clase) y “Fare” (tarifa del pasaje), para analizar los factores que podrían haber ayudado a alguien a sobrevivir al hundimiento.
# - Realiza un análisis estadístico utilizando métodos como pruebas de hipótesis o análisis de correlación para determinar la significancia estadística de estas variables en relación con la supervivencia.
#
# A partir de lo aprendido y estudiado en este ejercicio, ¿crees que podrías haber sobrevivido al accidente del Titanic? ¿Por qué?
#
# ### Conclusiones
#
# Responde cada una de las preguntas planteadas en el ejercicio utilizando los resultados obtenidos del análisis estadístico. Presenta tus conclusiones en un reporte de manera clara y concisa, respaldadas por evidencia estadística y visualizaciones adecuadas. Recuerda que el objetivo principal de este ejercicio es utilizar la estadística descriptiva para obtener información y responder las preguntas planteadas. Asegúrate de documentar y presentar tus resultados de manera organizada y comprensible.

# %% [markdown]
# ### Solución

# %% [markdown]
# #### Loading libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import io as io

# %% [markdown]
# #### Cargar datos
#
# Como información de entrada, hay dos archivos CSV:
#
# - `train.csv`: parte de entrenamiento del conjunto de datos, contiene etiquetas e información sobre los pasajeros.
# - `test.csv`: parte de prueba del conjunto de datos, no contiene etiquetas.
#
# En este cuaderno se utilizará toda la información disponible (conjuntos de datos de entrenamiento y prueba) para realizar un análisis exploratorio de datos.
#
# En primer lugar, se cargan ambos archivos CSV en dos DataFrames utilizando el método `read_csv` de pandas y se verifica la forma de los datos cargados.

# %%
# Read a comma-separated values (csv) file into pandas DataFrame
train_data = pd.read_csv("titanic_train.csv")
test_data = pd.read_csv("titanic_test.csv")

# shape of tha data
print("Train shape: ", train_data.shape)
print("Test shape: ", test_data.shape)
# Out:
# Train shape:  (891, 12)
# Test shape:  (418, 11)

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# La parte de entrenamiento contiene información sobre 891 pasajeros, descritos por 12 variables, incluyendo 1 variable objetivo. La parte de prueba contiene 418 observaciones, es decir, información sobre los pasajeros, descrita por 11 variables (el conjunto de datos de prueba no contiene el valor objetivo).
#
# Se combina los datos de prueba y entrenamiento en un DataFrame llamado "all_data". Para hacer esto, se crea una secuencia de objetos DataFrame y se utiliza el método `concat` de pandas. Los valores objetivo de los datos de prueba en el conjunto de datos resultante serán NaN. Se verifica la forma del DataFrame resultante y se observan las primeras 4 filas:

# %%
# create a sequence of DataFrame objects
frames = [train_data, test_data]
# Concatenate pandas objects along a particular axis 
all_data = pd.concat(frames, sort = False)
# shape of the data
print('All data shape: ', all_data.shape)
# Show first 4 rows of the concatenated DataFrame
all_data.head(5)
# Out:
# All data shape:  (1309, 12)
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
all_data.tail(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305       NaN       3            Spector, Mr. Woolf    male
# 414         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 416         1308       NaN       3           Ware, Mr. Frederick    male
# 417         1309       NaN       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# En general, se tiene información sobre 1309 pasajeros. Se supone que este conjunto de datos contiene solo información sobre los pasajeros, no sobre los miembros de la tripulación (se sabe que el Titanic transportaba a 2224 personas).

# %% [markdown]
# #### Primer vistazo: variables, NAs
#
# Es necesario identificar todas las variables, rangos, tipos de datos, etc. Esto se puede obtener a partir de la descripción del conjunto de datos.

# %% [markdown]
# ##### Variables
# * PassengerId: identificador único
# * Survived: 0 = no, 1 = sí
# * Pclass: Clase del ticket - 1 = 1ra clase (superior), 2 = 2da clase (media), 3 = 3ra clase (inferior)
# * Name: nombre completo con título
# * Sex: género
# * Age: La edad es fraccionaria si es menor de 1. Si la edad es estimada, se indica en forma de xx.5
# * Sibsp: Número de hermanos/cónyuges a bordo del Titanic. El conjunto de datos define las relaciones familiares de la siguiente manera: **Hermano(a)** = hermano, hermana, hermanastro, hermanastra; **Cónyuge** = esposo, esposa (se ignoraron amantes y prometidos).
# * Parch: Número de padres/hijos a bordo del Titanic. El conjunto de datos define las relaciones familiares de la siguiente manera: **Padre** = madre, padre; **Hijo(a)** = hija, hijo, hijastra, hijastro (algunos niños viajaban solo con una niñera, por lo tanto, **parch=0** para ellos).
# * Ticket: Número de ticket.
# * Fare: Tarifa del pasajero.
# * Cabin: Número de camarote.
# * Embarked: Puerto de embarque - **C** = Cherbourg; **Q** = Queenstown, **S** = Southampton

# %% [markdown]
# ##### Types of the variables

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %% [markdown]
# ##### Obteniendo algunas estadísticas de los datos.

# %%
all_data.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# ##### Verificando los datos en busca de valores faltantes (NA)
#
# Para verificar los valores NA en el conjunto de datos, se utiliza la función `isna()` del dataframe, la cual devuelve un objeto booleano del mismo tamaño indicando si los valores son NA. Luego, se calcula el número de valores True para cada variable. Los valores NA para cada dataframe (train, test, all) se presentan en la siguiente tabla:

# %%
# check data for NA values
all_data_NA = all_data.isna().sum()
train_NA = train_data.isna().sum()
test_NA = test_data.isna().sum()

pd.concat([train_NA, test_NA, all_data_NA], axis=1, sort = False, keys = ['Train NA', 'Test NA', 'All NA'])
# Out:
#              Train NA  Test NA  All NA
# PassengerId         0      0.0       0
# Survived            0      NaN     418
# Pclass              0      0.0       0
# Name                0      0.0       0
# Sex                 0      0.0       0
# Age               177     86.0     263
# SibSp               0      0.0       0
# Parch               0      0.0       0
# Ticket              0      0.0       0
# Fare                0      1.0       1
# Cabin             687    327.0    1014
# Embarked            2      0.0       2

# %% [markdown]
# En general, hay un total de 263 valores faltantes en la variable de Edad, 1 valor faltante en Fare, 1014 NAs en la variable Cabin y 2 en la variable Embarked. Hay 418 NA en la variable Survived debido a la ausencia de esta información en el conjunto de datos de prueba. No imputaré estos valores faltantes en el cuaderno actual. Por lo tanto, cuando utilice esta variable para visualización, solo habrá información disponible para la parte de entrenamiento de los datos.
#
# En este cuaderno, realizaré algunas técnicas para manejar los datos faltantes en el conjunto de datos combinado. Sin embargo, en la segunda parte de mi trabajo (solución de aprendizaje automático), esto se deberá hacer en base a lo que conocemos solo sobre los datos de entrenamiento, para evitar cualquier filtración de datos.

# %% [markdown]
# #### Explorando los datos

# %% [markdown]
# ##### Supervivencia: variable objetivo
#
# Se va a calcular y visualizar la distribución de la variable 'Survived'. Un `countplot` del módulo `seaborn` es una forma muy útil de mostrar el recuento de observaciones en cada categoría. Dado que solo se tiene el objetivo para la parte de entrenamiento, estos números no incluyen a todos los pasajeros.

# %%
# set size of the plot
plt.figure(figsize=(6, 4.5)) 

# countplot shows the counts of observations in each categorical bin using bars.
# x - name of the categorical variable
ax = sns.countplot(x = 'Survived', data = all_data, palette=["#3f3e6fd1", "#85c6a9"])

# set the current tick locations and labels of the x-axis.
plt.xticks( np.arange(2), ['drowned', 'survived'] )
# set title
plt.title('Overall survival (training dataset)',fontsize= 14)
# set x label
plt.xlabel('Passenger status after the tragedy')
# set y label
plt.ylabel('Number of passengers')

# calculate passengers for each category
labels = (all_data['Survived'].value_counts())
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v-40, str(v), horizontalalignment = 'center', size = 14, color = 'w', fontweight = 'bold')
    
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1054891241.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = 'Survived', data = all_data, palette=["#3f3e6fd1", "#85c6a9"])

# %%
all_data['Survived'].value_counts(normalize = True)
# Out:
# Survived
# 0.0    0.616162
# 1.0    0.383838
# Name: proportion, dtype: float64

# %% [markdown]
# En el conjunto de datos de entrenamiento, hay 891 pasajeros, de los cuales 549 (61,6%) se ahogaron y solo 342 (38,4%) sobrevivieron. Sin embargo, se sabe que los botes salvavidas podrían transportar al 53% del total de pasajeros.

# %% [markdown]
# ##### Edad
#
# Se analiza la edad de los pasajeros, cómo se relaciona con las posibilidades de supervivencia y cómo varía según la clase y el género.

# %% [markdown]
# Distribución de edades
#
# Se tienen 263 valores faltantes:
#
# - 177 faltantes en el conjunto de datos de entrenamiento
# - 86 faltantes en el conjunto de datos de prueba
#
# Distribución general de edades (`seaborn`, `distplot`) y estadísticas descriptivas:

# %%
# set plot size
plt.figure(figsize=(15, 3))

# plot a univariate distribution of Age observations 
sns.displot(all_data[(all_data["Age"] > 0)].Age, kde_kws={"lw": 3}, bins = 50)

# set titles and labels
plt.title('Distrubution of passengers age (all data)',fontsize= 14)
plt.xlabel('Age')
plt.ylabel('Frequency')
# clean layout
plt.tight_layout()

# %%
# Descriptive statistics include those that summarize the central tendency, 
# dispersion and shape of a dataset’s distribution, excluding NaN values.
age_distr = pd.DataFrame(all_data['Age'].describe())
# Transpose index and columns.
age_distr.transpose()
# Out:
#       count       mean        std   min   25%   50%   75%   max
# Age  1046.0  29.881138  14.413493  0.17  21.0  28.0  39.0  80.0

# %% [markdown]
# La distribución de la edad está ligeramente sesgada hacia la derecha. La edad varía desde aproximadamente 0.17 años hasta 80 años, con una media de 29.88, y no parece haber valores atípicos obvios, pero se comprobará.

# %% [markdown]
# Edad según el estado de supervivencia
#
# ¿Tuvo la edad una gran influencia en las posibilidades de sobrevivir? Para visualizar las distribuciones de edad, agrupadas por estado de supervivencia, estoy utilizando un boxplot y un stripplot mostrados juntos.

# %%
plt.figure(figsize=(15, 3))

# Draw a box plot to show Age distributions with respect to survival status.
sns.boxplot(y = 'Survived', x = 'Age', data = train_data,
     palette=["#3f3e6fd1", "#85c6a9"], fliersize = 0, orient = 'h')

# Add a scatterplot for each category.
sns.stripplot(y = 'Survived', x = 'Age', data = train_data,
     linewidth = 0.6, palette=["#3f3e6fd1", "#85c6a9"], orient = 'h')

plt.yticks( np.arange(2), ['drowned', 'survived'])
plt.title('Age distribution grouped by surviving status (train data)',fontsize= 14)
plt.ylabel('Passenger status after the tragedy')
plt.tight_layout()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/3623421144.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y = 'Survived', x = 'Age', data = train_data,
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/3623421144.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(y = 'Survived', x = 'Age', data = train_data,

# %%
# Descriptive statistics:
pd.DataFrame(all_data.groupby('Survived')['Age'].describe())
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0.0       424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1.0       290.0  28.343690  14.950952  0.42  19.0  28.0  36.0  80.0

# %% [markdown]
# Edad según el estado de supervivencia
#
# ¿Tuvo la edad una gran influencia en las posibilidades de sobrevivir? Para visualizar las distribuciones de edad, agrupadas por estado de supervivencia, se utiliza un boxplot y un stripplot mostrados juntos.

# %% [markdown]
# En realidad, el Sr. Algernon Henry Barkworth nació el 4 de junio de 1864. Tenía 48 años en 1912 y falleció en 1945 a los 80 años.

# %%
train_data.loc[train_data['PassengerId'] == 631, 'Age'] = 48
all_data.loc[all_data['PassengerId'] == 631, 'Age'] = 48

# %%
# Descriptive statistics:
pd.DataFrame(all_data.groupby('Survived')['Age'].describe())
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0.0       424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1.0       290.0  28.233345  14.684091  0.42  19.0  28.0  36.0  63.0

# %% [markdown]
# Se actualiza la descripción de la siguiente manera:
#
# La edad promedio de los pasajeros que sobrevivieron es de 28.23, lo cual es 2.39 años menor que la edad promedio de los pasajeros que se ahogaron (solo se consideran los pasajeros para los cuales se conoce su estado de supervivencia). La edad máxima de un pasajero que sobrevivió es de 63 años. Parece haber una ligera mayor probabilidad de sobrevivir para las personas más jóvenes.

# %% [markdown]
# Edad por clase
#
# Se compararán tres distribuciones de edad, agrupadas por clase del pasajero.
# Como visualizaciones se utilizarán 2 gráficos:
#
# 1- `boxplot` + `stripplot` como antes.
# 2- `kdeplot`, para trazar curvas de densidad de edad para cada clase. Este método no puede manejar valores faltantes, por lo que se filtra los datos antes de utilizarlo.

# %%
# set size
plt.figure(figsize=(20, 6))

# set palette
palette = sns.cubehelix_palette(5, start=3)

plt.subplot(1, 2, 1)
sns.boxplot(x='Pclass', y='Age', data=all_data.reset_index(),
            palette=palette, fliersize=0)

sns.stripplot(x='Pclass', y='Age', data=all_data.reset_index(),
              linewidth=0.6, palette=palette)
plt.xticks(np.arange(3), ['1st class', '2nd class', '3rd class'])
plt.title('Distribución de edad agrupada por clase de ticket (todos los datos)', fontsize=16)
plt.xlabel('Clase de ticket')

plt.subplot(1, 2, 2)

# Crear variables con datos filtrados para cada categoría
age_1_class = all_data[(all_data["Age"] > 0) &
                       (all_data["Pclass"] == 1)].reset_index()
age_2_class = all_data[(all_data["Age"] > 0) &
                       (all_data["Pclass"] == 2)].reset_index()
age_3_class = all_data[(all_data["Age"] > 0) &
                       (all_data["Pclass"] == 3)].reset_index()

# Graficar las tres variables creadas
sns.kdeplot(age_1_class["Age"], shade=True, color='#eed4d0', label='1st class')
sns.kdeplot(age_2_class["Age"], shade=True, color='#cda0aa', label='2nd class')
sns.kdeplot(age_3_class["Age"], shade=True, color='#a2708e', label='3rd class')
plt.title('Distribución de edad agrupada por clase de ticket (todos los datos)', fontsize=16)
plt.xlabel('Edad')
plt.xlim(0, 90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/880824678.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Age', data=all_data.reset_index(),
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/880824678.py:8: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(x='Pclass', y='Age', data=all_data.reset_index(),
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/880824678.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Pclass', y='Age', data=all_data.reset_index(),
# ...

# %%
# Descriptive statistics:
pd.DataFrame(all_data.groupby('Pclass')['Age'].describe())
# Out:
#         count       mean        std   min   25%   50%    75%   max
# Pclass
# 1       284.0  39.047254  14.353217  0.92  28.0  39.0  49.25  76.0
# 2       261.0  29.506705  13.638627  0.67  22.0  29.0  36.00  70.0
# 3       501.0  24.816367  11.958202  0.17  18.0  24.0  32.00  74.0

# %% [markdown]
# La primera clase tiene una distribución más amplia en comparación con la segunda y tercera clase, y es casi simétrica. Ambas distribuciones de edad de la segunda y tercera clase están sesgadas hacia la derecha. El pasajero más joven tiene un ticket de tercera clase y una edad de 0.17. El pasajero más viejo tiene un ticket de primera clase y una edad de 76. La edad promedio de la tercera clase es de 24.8, la edad promedio de la segunda clase es de 29.5 y la edad promedio de la primera clase es de 39.1.
#
# Dado que en promedio los pasajeros que sobrevivieron eran más jóvenes que los que se ahogaron, ¿significa esto que los pasajeros de tercera clase tenían más posibilidades de sobrevivir? Lo descubriremos más adelante.
#
# A partir de los gráficos, podemos observar diferencias en la distribución de edades entre las clases. Por lo tanto, al realizar la imputación de datos faltantes, se tendrá en cuenta la clase del pasajero.

# %% [markdown]
# Edad vs. clase vs. género
#
# Comparación de la distribución de edades por género se realizará de forma separada para cada clase, ya que existe una diferencia notable de edad entre las clases.

# %%
plt.figure(figsize=(20, 5))
palette = "Set3"

plt.subplot(1, 3, 1)
sns.boxplot(x = 'Sex', y = 'Age', data = age_1_class,
     palette = palette, fliersize = 0)
sns.stripplot(x = 'Sex', y = 'Age', data = age_1_class,
     linewidth = 0.6, palette = palette)
plt.title('1st class Age distribution by Sex',fontsize= 14)
plt.ylim(-5, 80)

plt.subplot(1, 3, 2)
sns.boxplot(x = 'Sex', y = 'Age', data = age_2_class,
     palette = palette, fliersize = 0)
sns.stripplot(x = 'Sex', y = 'Age', data = age_2_class,
     linewidth = 0.6, palette = palette)
plt.title('2nd class Age distribution by Sex',fontsize= 14)
plt.ylim(-5, 80)

plt.subplot(1, 3, 3)
sns.boxplot(x = 'Sex', y = 'Age',  data = age_3_class,
     order = ['female', 'male'], palette = palette, fliersize = 0)
sns.stripplot(x = 'Sex', y = 'Age', data = age_3_class,
     order = ['female', 'male'], linewidth = 0.6, palette = palette)
plt.title('3rd class Age distribution by Sex',fontsize= 14)
plt.ylim(-5, 80)

plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/2954139959.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Sex', y = 'Age', data = age_1_class,
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/2954139959.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x = 'Sex', y = 'Age', data = age_1_class,
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/2954139959.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Sex', y = 'Age', data = age_2_class,
# ...

# %%
# Descriptive statistics:
age_1_class_stat = pd.DataFrame(age_1_class.groupby('Sex')['Age'].describe())
age_2_class_stat = pd.DataFrame(age_2_class.groupby('Sex')['Age'].describe())
age_3_class_stat = pd.DataFrame(age_3_class.groupby('Sex')['Age'].describe())

pd.concat([age_1_class_stat, age_2_class_stat, age_3_class_stat], axis=0, sort = False, keys = ['1st', '2nd', '3rd'])
# Out:
#             count       mean        std   min   25%   50%    75%   max
#     Sex
# 1st female  133.0  37.037594  14.272460  2.00  24.0  36.0  48.00  76.0
#     male    151.0  40.817351  14.236835  0.92  30.0  42.0  50.00  71.0
# 2nd female  103.0  27.499223  12.911747  0.92  20.0  28.0  34.00  60.0
#     male    158.0  30.815380  13.977400  0.67  23.0  29.5  38.75  70.0
# 3rd female  152.0  22.185329  12.205254  0.17  16.0  22.0  30.00  63.0
#     male    349.0  25.962264  11.682415  0.33  20.0  25.0  32.00  74.0

# %% [markdown]
# La pasajera más joven y la pasajera más anciana son mujeres. En cada clase, la edad promedio de las mujeres es ligeramente menor que la edad promedio de los pasajeros masculinos.

# %% [markdown]
# ##### ¿Qué hay en el nombre?
#
# Cada valor del nombre del pasajero contiene el título del pasajero, que podemos extraer y descubrir. Luego se crea una nueva variable llamada "Título":
#
# 1. Se utiliza el método 'split' mediante una coma para dividir el nombre en dos partes y se guarda la segunda parte.
# 2. Se divide la parte guardada mediante un punto y se guarda la primera parte del resultado.
# 3. Para eliminar los espacios alrededor del título se utiliza el método 'split'.
#
# Para visualizar cuántos pasajeros tienen cada título, se utiliza un gráfico de conteo (countplot).

# %%
all_data['Title'] = all_data['Name'].str.split(',', expand = True)[1].str.split('.', expand = True)[0].str.strip(' ')

plt.figure(figsize=(6, 5))
ax = sns.countplot( x = 'Title', data = all_data, palette = "hls", order = all_data['Title'].value_counts().index)
_ = plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'  
)

plt.title('Passengers distribution by titles',fontsize= 14)
plt.ylabel('Number of passengers')

# calculate passengers for each category
labels = (all_data['Title'].value_counts())
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v+10, str(v), horizontalalignment = 'center', size = 10, color = 'black')
    

plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/3628672919.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot( x = 'Title', data = all_data, palette = "hls", order = all_data['Title'].value_counts().index)

# %% [markdown]
# El título más frecuente entre los pasajeros es **Mister** (Sr.) - un título general o de respeto para un hombre adulto. El segundo título más frecuente es **Miss** (señorita) - una mujer soltera, y el tercero es **Mrs**. (mujer casada). Otros títulos son menos frecuentes, pero descubriré si puedo combinarlos en grupos particulares. Utilizaré los títulos como una característica, pero si dividen los datos demasiado, dejando solo unas pocas observaciones en cada grupo, puede llevar a un sobreajuste (overfitting). Y para una comprensión general de los datos, será más conveniente agrupar los títulos de manera más clara.
#
# **Master** - A finales del siglo XIX, el protocolo dictaba que los hombres fueran tratados como **Mister**, y los niños como **Master**.
#
# **Mme** - Madame. Un título francés de respeto equivalente a **Mrs**, utilizado solo o antes del nombre o título de casada de una mujer. Lo agregaré a **Mrs**.
#
# **Mlle** - Mademoiselle es un título cortés en francés, abreviado como **Mlle**, tradicionalmente otorgado a una mujer soltera. El equivalente en inglés es **Miss**. Lo agregaré al grupo de **Miss**.
#
# **Dr**. - Doctor es un título académico.
#
# **Rev**. - Reverendo, es generalmente un título de cortesía para ministros o pastores cristianos protestantes.
#
# Grupo militar de títulos:
# - **Capt**. - Capitán es un título para el comandante de una unidad militar.
# - **Major** es un rango militar de oficial comisionado.
# - **Col**. - El título honorífico de Coronel se confiere en varios estados de los Estados Unidos y en ciertas unidades militares de la Commonwealth de Naciones.
#
# Grupo de títulos de honor:
# - **Sir** - es un título honorífico formal en inglés para hombres. **Sir** se utiliza para hombres que tienen el título de caballeros, es decir, de órdenes de caballería, y posteriormente también para baronetes y otros cargos.
# - **the Countess** - es un título histórico de nobleza.
# - **Lady** - un título formal en el Reino Unido. Una mujer con un título de nobleza u honorario.
# - **Jonkheer** - es un título honorífico en los Países Bajos que denota el rango más bajo dentro de la nobleza.
#
# - **Don** - es un prefijo honorífico utilizado principalmente en España y el antiguo Imperio Español, Italia, Portugal, Filipinas, América Latina, Croacia y Goa. (hombre)
# - **Dona** - Forma femenina de don (honorífico) en español, portugués, italiano meridional y filipino, utilizado como marca de respeto.
#
# No estoy seguro sobre el título "Ms", solo tenemos 2 pasajeros con este título, lo convertiré a "Miss". He creado un diccionario de títulos y estoy utilizando el método "map" para crear la variable "Title_category".

# %%
all_data[all_data['Title']=='Ms']
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 443          444       1.0       2  Reynaldo, Ms. Encarnacion  female  28.0
# 88           980       NaN       3    O'Donoghue, Ms. Bridget  female   NaN
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked Title
# 443      0      0  230434  13.00   NaN        S    Ms
# 88       0      0  364856   7.75   NaN        Q    Ms

# %%
title_dict = {  'Mr':     'Mr',
                'Mrs':    'Mrs',
                'Miss':   'Miss',
                'Master': 'Master',
              
                'Ms':     'Miss',
                'Mme':    'Mrs',
                'Mlle':   'Miss',

                'Capt':   'military',
                'Col':    'military',
                'Major':  'military',

                'Dr':     'Dr',
                'Rev':    'Rev',
                  
                'Sir':    'honor',
                'the Countess': 'honor',
                'Lady':   'honor',
                'Jonkheer': 'honor',
                'Don':    'honor',
                'Dona':   'honor' }

# map titles to category
all_data['Title_category'] = all_data['Title'].map(title_dict)

# %%
fig = plt.figure(figsize=(12, 5))


ax1 = fig.add_subplot(121)
ax = sns.countplot(x = 'Title_category', data = all_data, palette = "hls", order = all_data['Title_category'].value_counts().index)
_ = plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'  
)
plt.title('Passengers distribution by titles',fontsize= 12)
plt.ylabel('Number of passengers')

# calculate passengers for each category
labels = (all_data['Title_category'].value_counts())
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v+10, str(v), horizontalalignment = 'center', size = 10, color = 'black')
    

plt.tight_layout()

ax2 = fig.add_subplot(122)
surv_by_title_cat = all_data.groupby('Title_category')['Survived'].value_counts(normalize = True).unstack()
surv_by_title_cat = surv_by_title_cat.sort_values(by=1, ascending = False)
surv_by_title_cat.plot(kind='bar', stacked='True', color=["#3f3e6fd1", "#85c6a9"], ax = ax2)

plt.legend( ( 'Drowned', 'Survived'), loc=(1.04,0))
_ = plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'  
)


plt.title('Proportion of survived/drowned by titles (train data)',fontsize= 12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1222919781.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x = 'Title_category', data = all_data, palette = "hls", order = all_data['Title_category'].value_counts().index)

# %% [markdown]
# El grupo más pequeño es el de "honor", que incluye a los pasajeros con títulos de tipo real.
#
# Datos de entrenamiento:
# - La mayor proporción de sobrevivientes se encuentra en el grupo "Mrs" - mujeres casadas.
# - Más del 80% de los pasajeros del grupo "Mr." se ahogaron.
# - Nadie sobrevivió en el grupo de Reverendos.

# %%
category_survived = sns.catplot(x="Title_category",  col="Survived",
                data = all_data, kind="count",
                height=4, aspect=.7)

category_survived.set_xticklabels(rotation=45, 
    horizontalalignment='right',
    fontweight='light')

plt.tight_layout()

# %% [markdown]
# Si consideramos a los sobrevivientes no porcentaje dentro de cada grupo, sino comparando el número de sobrevivientes entre grupos, entonces la categoría de título **Miss** es la más afortunada. La categoría **Mr** perdió el mayor número de pasajeros.
#
# También visualicemos cómo se relacionan las categorías de título y las clases de boletos:

# %%
class_by_title_cat = all_data.groupby('Title_category')['Pclass'].value_counts(normalize = True)
class_by_title_cat = class_by_title_cat.unstack().sort_values(by = 1, ascending = False)
class_by_title_cat.plot(kind='bar', stacked='True', color = ['#eed4d0', '#cda0aa', '#a2708e'])
plt.legend(loc=(1.04,0))
_ = plt.xticks(
    rotation = 45, 
    horizontalalignment = 'right',
    fontweight = 'light'  
)

plt.title('Proportion of 1st/2nd/3rd ticket class in each title category',fontsize= 14)
plt.xlabel('Category of the Title')
plt.tight_layout()

# %% [markdown]
# - Todos los títulos de honor y militares ocuparon la 1ra clase.
# - Todos los Reverendos ocuparon la 2da clase.
# - El mayor porcentaje de la 3ra clase se encuentra en la categoría de Maestros (Master).
#
# Sin duda, existe una relación entre las variables, y la supervivencia no solo fue influenciada por el título en sí, sino por una combinación de factores que están interrelacionados en cierta medida. ¿Cómo podría relacionarse la clase con la supervivencia? Sigamos adelante y descubrámoslo.

# %% [markdown]
# ##### Cabina
#
# https://www.encyclopedia-titanica.org/titanic-deckplans/
#
# A partir del número de la cabina, podemos extraer la primera letra, ¡lo cual nos dirá la ubicación de la cabina en el barco! Y me parece un conocimiento muy importante:
#
# - Qué tan cerca está ubicada la cabina de los botes salvavidas.
# - Qué tan lejos de las partes más dañadas del barco.
# - Qué tan cerca de las personas que tienen información sobre lo que está sucediendo y cómo actuar.
# - Cuántos obstáculos tuvo el pasajero en el camino hacia el bote salvavidas.
#
# Encontré algunas descripciones de cada cubierta del Titanic. Había 8 cubiertas: la cubierta superior para los botes salvavidas, y las otras 7 se encontraban debajo y tenían símbolos de letras:
#
# - **A**: no recorría toda la longitud del barco (es decir, no llegaba desde la popa hasta la proa del barco) y estaba destinada a pasajeros de 1ra clase.
# - **B**: no recorría toda la longitud del barco (se interrumpía a 37 metros por encima de la cubierta C) y servía como lugar para los anclajes en la parte delantera.
# - **C**: en la parte delantera se encontraba la cocina, el comedor de la tripulación, así como un área de paseo para pasajeros de 3ra clase.
# - **D**: un área de paseo para pasajeros.
# - **E**: cabinas de 1ra y 2da clase.
# - **F**: parte de las cabinas de pasajeros de 2da clase y la mayoría de las cabinas de 3ra clase.
# - **G**: no recorría toda la longitud del barco, las salas de calderas se encontraban en el centro.
# - **T**: ¿cubierta de botes?
#
# Para los pasajeros sin información sobre la cubierta, asignaré la letra **U** (desconocido).

# %%
all_data['deck'] = all_data['Cabin'].str.split('', expand = True)[1]
all_data.loc[all_data['deck'].isna(), 'deck'] = 'U'
print('Unique deck letters from the cabin numbers:', all_data['deck'].unique())
# Out:
# Unique deck letters from the cabin numbers: ['U' 'C' 'E' 'G' 'D' 'A' 'B' 'F' 'T']

# %%
fig = plt.figure(figsize=(20, 5))

ax1 = fig.add_subplot(131)
sns.countplot(x = 'deck', data = all_data, palette = "hls", order = all_data['deck'].value_counts().index, ax = ax1)
plt.title('Passengers distribution by deck',fontsize= 16)
plt.ylabel('Number of passengers')

ax2 = fig.add_subplot(132)
deck_by_class = all_data.groupby('deck')['Pclass'].value_counts(normalize = True).unstack()
deck_by_class.plot(kind='bar', stacked='True',color = ['#eed4d0', '#cda0aa', '#a2708e'], ax = ax2)
plt.legend(('1st class', '2nd class', '3rd class'), loc=(1.04,0))
plt.title('Proportion of classes on each deck',fontsize= 16)
plt.xticks(rotation = False)

ax3 = fig.add_subplot(133)
deck_by_survived = all_data.groupby('deck')['Survived'].value_counts(normalize = True).unstack()
deck_by_survived = deck_by_survived.sort_values(by = 1, ascending = False)
deck_by_survived.plot(kind='bar', stacked='True', color=["#3f3e6fd1", "#85c6a9"], ax = ax3)
plt.title('Proportion of survived/drowned passengers by deck',fontsize= 16)
plt.legend(( 'Drowned', 'Survived'), loc=(1.04,0))
plt.xticks(rotation = False)
plt.tight_layout()

plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/768272938.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'deck', data = all_data, palette = "hls", order = all_data['deck'].value_counts().index, ax = ax1)

# %% [markdown]
# La mayoría de los pasajeros no tienen números de cabina ('U'). La mayor parte de los pasajeros con números de cabina conocidos se encontraban en la cubierta 'C' y tenían boleto de 1ra clase. La cubierta 'C' ocupa el quinto lugar en términos de porcentaje de supervivencia. La tasa de supervivencia más alta (entre los pasajeros con números de cabina conocidos en el conjunto de datos de entrenamiento) la tuvieron los pasajeros de la cubierta 'D'. La cubierta A estaba más cerca de la cubierta con los botes salvavidas, pero ocupa el último lugar en términos de tasa de supervivencia (excepto por desconocido y la cubierta T). ¿Cómo sucedió esto?

# %%
all_data[(all_data['deck']=='A') & (all_data['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97       0.0       1             Goldschmidt, Mr. George B
# 174          175       0.0       1               Smith, Mr. James Clinch
# 185          186       0.0       1                 Rood, Mr. Hugh Roscoe
# 284          285       0.0       1            Smith, Mr. Richard William
# 475          476       0.0       1           Clifford, Mr. George Quincy
# 583          584       0.0       1                   Ross, Mr. John Hugo
# 806          807       0.0       1                Andrews, Mr. Thomas Jr
# 867          868       0.0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked Title  \
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C    Mr
# 174  male  56.0      0      0     17764  30.6958    A7        C    Mr
# 185  male   NaN      0      0    113767  50.0000   A32        S    Mr
# ...

# %% [markdown]
# Hay algunos casos que son curiosos, así que se investigó sobre algunos de estos pasajeros:
#
# - John Hugo Ross (https://www.encyclopedia-titanica.org/titanic-victim/john-hugo-ross.html). Cuando embarcó el 10 de abril de 1912, estaba tan enfermo de disentería que tuvo que ser llevado a su cabina en una camilla. Cuando a Ross le dijeron que el barco había chocado con un iceberg y que debía vestirse, él se negó a creer que el problema era grave. "¿Es todo?", le dijo a Peuchen. "Se necesitará más que un iceberg para sacarme de este barco". Presumiblemente, Ross se ahogó en su cama.
#
# - Andrews, Sr. Thomas Jr. (https://en.wikipedia.org/wiki/Thomas_Andrews) era el director gerente de H&W (constructora del Titanic) a cargo del diseño y estaba familiarizado con cada detalle de la construcción de los barcos de la empresa. Ayudó a evacuar a las personas.
#
# - Roebling, Sr. Washington Augustus II (https://www.encyclopedia-titanica.org/titanic-victim/washington-roebling.html) también ayudó a evacuar a las personas.
#
# Es evidente que no existe un algoritmo que pueda predecir la tasa de supervivencia al 100 por ciento basado en factores como la ubicación del pasajero en el barco o su edad, ya que el factor humano y la emergencia imprevista estuvieron involucrados en el proceso de rescate.
#
# Para el proceso de entrenamiento, sería mejor incluir a los pasajeros de la cubierta T en el grupo de la cubierta A.

# %% [markdown]
# ##### Familia
#
# ¿Influye el tamaño de la familia a bordo en las posibilidades de sobrevivir a un desastre? ¿Tener hijos aumenta la posibilidad de subir a un bote, o es más fácil sobrevivir siendo soltero? Calculo el tamaño de la familia sumando el número de hermanos con el número de padres/hijos (parch) más 1 (el propio pasajero). El tamaño de la familia = sib + parch + 1.

# %% [markdown]
# Calculate family size

# %%
all_data['Family_size'] = all_data['SibSp'] + all_data['Parch'] + 1
family_size = all_data['Family_size'].value_counts()
print('Family size and number of passengers:')
print(family_size)
# Out:
# Family size and number of passengers:
# Family_size
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: count, dtype: int64

# %% [markdown]
# Resulta extraño que haya 16 pasajeros con un tamaño de familia de 7, por ejemplo. ¡Vamos a verificarlo! Además, agregaré una variable de apellido extrayendo la primera palabra del nombre.

# %%
all_data['Surname'] = all_data['Name'].str.split(',', expand = True)[0]

# %% [markdown]
# ¿Familia de 7 personas? Agrupemos a las personas con un tamaño de familia igual a 7 por apellido. Tenemos 9 personas con el apellido Anderson que tienen un tamaño de familia de 7.

# %%
all_data[all_data['Family_size'] == 7]['Surname'].value_counts()
# Out:
# Surname
# Andersson    9
# Asplund      7
# Name: count, dtype: int64

# %%
all_data[(all_data['Family_size'] == 7) & (all_data['Surname']=='Andersson')]
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14       0.0       3
# 68            69       1.0       3
# 119          120       0.0       3
# 541          542       0.0       3
# 542          543       0.0       3
# 610          611       0.0       3
# 813          814       0.0       3
# 850          851       0.0       3
# 214         1106       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 68                     Andersson, Miss. Erna Alexandra  female  17.0      4
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541               Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                  Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# ...

# %% [markdown]
# Se debe agrupar a los Anderson con una familia de tamaño 7 según el número de boleto. Hay 7 personas que utilizaron el mismo boleto y viajaron juntas. 5 niños (cada uno de ellos tiene 4 hermanos) y 2 padres. Hay otros pasajeros que utilizaron boletos separados.

# %%
all_data[(all_data['Family_size'] == 7) & (all_data['Surname']=='Andersson')].Ticket.value_counts()
# Out:
# Ticket
# 347082     7
# 3101281    1
# 347091     1
# Name: count, dtype: int64

# %%
all_data[(all_data['Ticket'] == '3101281') | (all_data['Ticket'] == '347091')]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 68            69       1.0       3         Andersson, Miss. Erna Alexandra
# 214         1106       NaN       3  Andersson, Miss. Ida Augusta Margareta
#
#         Sex   Age  SibSp  Parch   Ticket   Fare Cabin Embarked Title  \
# 68   female  17.0      4      2  3101281  7.925   NaN        S  Miss
# 214  female  38.0      4      2   347091  7.775   NaN        S  Miss
#
#     Title_category deck  Family_size    Surname
# 68            Miss    U            7  Andersson
# 214           Miss    U            7  Andersson

# %% [markdown]
# Parece que en realidad viajaron solos, corregiré esos datos.

# %%
all_data.loc[all_data['PassengerId'] == 69, ['SibSp', 'Parch', 'Family_size']] = [0,0,1]
all_data.loc[all_data['PassengerId'] == 1106, ['SibSp', 'Parch', 'Family_size']] = [0,0,1]
all_data[(all_data['Ticket'] == '3101281') | (all_data['Ticket'] == '347091')]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 68            69       1.0       3         Andersson, Miss. Erna Alexandra
# 214         1106       NaN       3  Andersson, Miss. Ida Augusta Margareta
#
#         Sex   Age  SibSp  Parch   Ticket   Fare Cabin Embarked Title  \
# 68   female  17.0      0      0  3101281  7.925   NaN        S  Miss
# 214  female  38.0      0      0   347091  7.775   NaN        S  Miss
#
#     Title_category deck  Family_size    Surname
# 68            Miss    U            1  Andersson
# 214           Miss    U            1  Andersson

# %% [markdown]
# ¿Familia de 5 personas? Hay algunas inconsistencias en otras categorías, con menos parientes. Verifiquemos a las personas con un tamaño de familia de 5 y agrupémoslas por apellido:

# %%
all_data[all_data['Family_size'] == 5]['Surname'].value_counts()
# Out:
# Surname
# Palsson          5
# Ford             5
# Lefebre          5
# Ryerson          5
# Hocking          1
# Kink-Heilmann    1
# Name: count, dtype: int64

# %%
all_data[all_data['Family_size'] == 5]['Surname'].value_counts()
# Out:
# Surname
# Palsson          5
# Ford             5
# Lefebre          5
# Ryerson          5
# Hocking          1
# Kink-Heilmann    1
# Name: count, dtype: int64

# %% [markdown]
# Kink-Heilmann, el Sr. Anton tenía otros 2 hermanos en el barco, a diferencia de su esposa, para quien estos parientes no se ajustan a la descripción de parientes en el conjunto de datos. Supondremos que todas las demás "inconsistencias" en los grupos son similares a esta. Dado que planeo agrupar el tamaño de las familias en grupos, esto eliminará posibles inconsistencias.

# %% [markdown]
# Tamaño de la familia y las probabilidades de supervivencia

# %%
fig = plt.figure(figsize = (12,4))

ax1 = fig.add_subplot(121)
ax = sns.countplot(x = 'Family_size', data = all_data, hue = 'Family_size', palette="Set3")

# calculate passengers for each category
labels = (all_data['Family_size'].value_counts())
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v+6, str(v), horizontalalignment = 'center', size = 10, color = 'black')
    
plt.title('Passengers distribution by family size')
plt.ylabel('Number of passengers')

ax2 = fig.add_subplot(122)
d = all_data.groupby('Family_size')['Survived'].value_counts(normalize = True).unstack()
d.plot(kind='bar', color=["#3f3e6fd1", "#85c6a9"], stacked='True', ax = ax2)
plt.title('Proportion of survived/drowned passengers by family size (train data)')
plt.legend(( 'Drowned', 'Survived'), loc=(1.04,0))
plt.xticks(rotation = False)

plt.tight_layout()

# %% [markdown]
# - Hubo dos familias grandes con tamaños de 8 y 11 personas, y todos sus miembros del conjunto de datos de entrenamiento se ahogaron.
# - La mayoría de los pasajeros viajaban solos, el porcentaje de supervivencia no es muy alto.
# - La mayor proporción de pasajeros sobrevivientes se encuentra en el grupo de personas que tenían 4 miembros de la familia a bordo.
#
# Podemos observar que el porcentaje de supervivientes en las personas que tienen una familia de 2, 3 o 4 personas es mayor que en las personas que viajan solas, luego el porcentaje de supervivientes disminuye a medida que aumenta el tamaño de la familia. Crearé una variable **Family_size_group** con cuatro categorías:
#
# - soltero/a
# - habitual (tamaños 2, 3, 4)
# - grande (5, 6, 7)
# - y grande (todos los tamaños mayores que 7)

# %%
all_data['Family_size_group'] = all_data['Family_size'].map(lambda x: 'f_single' if x == 1 
                                                            else ('f_usual' if 5 > x >= 2 
                                                                  else ('f_big' if 8 > x >= 5 
                                                                       else 'f_large' )
                                                                 ))

# %%
fig = plt.figure(figsize = (14,5))

ax1 = fig.add_subplot(121)
d = all_data.groupby('Family_size_group')['Survived'].value_counts(normalize = True).unstack()
d = d.sort_values(by = 1, ascending = False)
d.plot(kind='bar', stacked='True', color = ["#3f3e6fd1", "#85c6a9"], ax = ax1)
plt.title('Proportion of survived/drowned passengers by family size (training data)')
plt.legend(( 'Drowned', 'Survived'), loc=(1.04,0))
_ = plt.xticks(rotation=False)


ax2 = fig.add_subplot(122)
d2 = all_data.groupby('Family_size_group')['Pclass'].value_counts(normalize = True).unstack()
d2 = d2.sort_values(by = 1, ascending = False)
d2.plot(kind='bar', stacked='True', color = ['#eed4d0', '#cda0aa', '#a2708e'], ax = ax2)
plt.legend(('1st class', '2nd class', '3rd class'), loc=(1.04,0))
plt.title('Proportion of 1st/2nd/3rd ticket class in family group size')
_ = plt.xticks(rotation=False)

plt.tight_layout()

# %% [markdown]
# Las familias grandes son todas de tercera clase y nadie de la parte de entrenamiento del conjunto de datos sobrevivió. La mayor proporción de personas de primera clase se encuentra en el tamaño habitual de la familia y la proporción de sobrevivientes en la familia habitual es la más alta.

# %% [markdown]
# #### Clase
#
# Se han realizado varias suposiciones sobre la tasa de supervivencia en función de las clases. Ahora es momento de examinar de cerca esta variable.

# %% [markdown]
# Pasajeros por clase

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))

class_counts = all_data['Pclass'].value_counts(sort=False)
ax = sns.barplot(x=class_counts.index, y=class_counts, palette=['#eed4d0', '#cda0aa', '#a2708e'])

# Agregar los números de resultado en el gráfico de barras
for i, v in enumerate(class_counts):
    ax.text(i, v + 2, str(v), horizontalalignment='center', size=12, color='black', fontweight='bold')

plt.title('Distribución de pasajeros por clase')
plt.ylabel('Número de pasajeros')
plt.xlabel('Clase')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/2460340352.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=class_counts.index, y=class_counts, palette=['#eed4d0', '#cda0aa', '#a2708e'])

# %% [markdown]
# La mayoría de los pasajeros del Titanic viajaban en tercera clase (709). La segunda clase es la más pequeña en términos de número de pasajeros.

# %% [markdown]
# Clase vs supervivencia

# %%
fig = plt.figure(figsize=(14, 5))

ax1 = fig.add_subplot(121)
sns.countplot(x = 'Pclass', hue = 'Survived', data = all_data, palette=["#3f3e6fd1", "#85c6a9"], ax = ax1)
plt.title('Number of survived/drowned passengers by class (train data)')
plt.ylabel('Number of passengers')
plt.legend(( 'Drowned', 'Survived'), loc=(1.04,0))
_ = plt.xticks(rotation=False)

ax2 = fig.add_subplot(122)
d = all_data.groupby('Pclass')['Survived'].value_counts(normalize = True).unstack()
d.plot(kind='bar', stacked='True', ax = ax2, color =["#3f3e6fd1", "#85c6a9"])
plt.title('Proportion of survived/drowned passengers by class (train data)')
plt.legend(( 'Drowned', 'Survived'), loc=(1.04,0))
_ = plt.xticks(rotation=False)

plt.tight_layout()

# %% [markdown]
# A pesar de los requisitos previamente identificados (en promedio, las personas mayores tienen más probabilidades de fallecer, y en primera clase, la edad promedio es mayor que en otras clases. Además, los pasajeros en la cubierta A, que consiste en un 100% de primera clase, tienen una gran proporción de pasajeros fallecidos), la primera clase tiene el mayor número de sobrevivientes y la proporción de sobrevivientes dentro de la clase es la más alta. Los boletos de tercera clase tuvieron el mayor número de pasajeros fallecidos y la mayoría de los pasajeros de tercera clase se ahogaron.

# %% [markdown]
# Clase vs Estado de supervivencia vs Género

# %%
sns.catplot(x = 'Pclass', hue = 'Survived', col = 'Sex', kind = 'count', data = all_data , palette=["#3f3e6fd1", "#85c6a9"])

plt.tight_layout()

# %% [markdown]
# Sin embargo, la mayoría de los pasajeros hombres de primera clase se ahogaron, mientras que casi todas las mujeres sobrevivieron. En la tercera clase, aproximadamente la mitad de las mujeres lograron sobrevivir.

# %% [markdown]
# Clase vs. Género vs. Edad -> Estado de supervivencia
#
# Para comprender mejor cómo la combinación de algunos factores influye en las posibilidades de sobrevivir, dividiremos a los pasajeros en 18 grupos imaginarios separados por:
#
# - Clase (1 / 2 / 3)
# - Género (hombre / mujer)
# - Edad (<16 / 16-40 / 40<)

# %%
plt.figure(figsize=(20, 10))
palette=["#3f3e6fd1", "#85c6a9"]

plt.subplot(2, 3, 1)
sns.stripplot(x = 'Survived', y = 'Age', data = age_1_class[age_1_class['Sex']=='male'],
     linewidth = 0.9, palette = palette)
plt.axhspan(0, 16, color = "#e1f3f6")
plt.axhspan(16, 40, color = "#bde6dd")
plt.axhspan(40, 80, color = "#83ceb9")
plt.title('Age distribution (males, 1st class)',fontsize= 14)
plt.xticks( np.arange(2), ['drowned', 'survived'])
plt.ylim(0, 80)

plt.subplot(2, 3, 2)
sns.stripplot(x = 'Survived', y = 'Age', data = age_2_class[age_2_class['Sex']=='male'],
     linewidth = 0.9, palette = palette)
plt.axhspan(0, 16, color = "#e1f3f6")
plt.axhspan(16, 40, color = "#bde6dd")
plt.axhspan(40, 80, color = "#83ceb9")
plt.title('Age distribution (males, 2nd class)',fontsize= 14)
plt.xticks( np.arange(2), ['drowned', 'survived'])
plt.ylim(0, 80)

plt.subplot(2, 3, 3)
sns.stripplot(x = 'Survived', y = 'Age', data = age_3_class[age_3_class['Sex']=='male'],
              linewidth = 0.9, palette = palette)
plt.axhspan(0, 16, color = "#e1f3f6")
plt.axhspan(16, 40, color = "#bde6dd")
plt.axhspan(40, 80, color = "#83ceb9")
plt.title('Age distribution (males, 3rd class)',fontsize= 14)
plt.xticks( np.arange(2), ['drowned', 'survived'])
plt.ylim(0, 80)


plt.subplot(2, 3, 4)
sns.stripplot(x = 'Survived', y = 'Age', data = age_1_class[age_1_class['Sex']=='female'],
     linewidth = 0.9, palette = palette)
plt.axhspan(0, 16, color = "#ffff9978")
plt.axhspan(16, 40, color = "#ffff97bf")
plt.axhspan(40, 80, color = "#ffed97bf")
plt.title('Age distribution (females, 1st class)',fontsize= 14)
plt.xticks( np.arange(2), ['drowned', 'survived'])
plt.ylim(0, 80)

plt.subplot(2, 3, 5)
sns.stripplot(x = 'Survived', y = 'Age', data = age_2_class[age_2_class['Sex']=='female'],
     linewidth = 0.9, palette = palette)
plt.axhspan(0, 16, color = "#ffff9978")
plt.axhspan(16, 40, color = "#ffff97bf")
plt.axhspan(40, 80, color = "#ffed97bf")
plt.title('Age distribution (females, 2nd class)',fontsize= 14)
plt.xticks( np.arange(2), ['drowned', 'survived'])
plt.ylim(0, 80)

plt.subplot(2, 3, 6)
sns.stripplot(x = 'Survived', y = 'Age', data = age_3_class[age_3_class['Sex']=='female'],
              linewidth = 0.9, palette = palette)
plt.axhspan(0, 16, color = "#ffff9978")
plt.axhspan(16, 40, color = "#ffff97bf")
plt.axhspan(40, 80, color = "#ffed97bf")
plt.title('Age distribution (females, 3rd class)',fontsize= 14)
plt.xticks( np.arange(2), ['drowned', 'survived'])
plt.ylim(0, 80)


plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1713652996.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x = 'Survived', y = 'Age', data = age_1_class[age_1_class['Sex']=='male'],
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1713652996.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x = 'Survived', y = 'Age', data = age_2_class[age_2_class['Sex']=='male'],
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1713652996.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# A partir de estos gráficos (solo datos de entrenamiento) podemos observar lo siguiente:
#
# - Solo un niño (<16) de las clases 1 y 2 se ahogó (una niña de la clase 1).
# - Sin embargo, los niños de la clase 3 no tuvieron tanta suerte, parece que las posibilidades de sobrevivir para los pasajeros menores de 16 años fueron del 50% tanto para hombres como para mujeres.
# - La mayoría de las mujeres de las clases 1 y 2 sobrevivieron, sin mucha diferencia en la edad.
# - Las mujeres de la clase 3 en el grupo de edad de 40+ se ahogaron, excepto una.
# - Una imagen similar se observa en hombres de las clases 2 y 3 en el grupo de edad de 40+: solo 2 de cada clase sobrevivieron.
# - Para hombres de 40+ de la clase 1, la situación fue ligeramente diferente, hay más pasajeros sobrevivientes.
# - La mayor "acumulación" de pasajeros ahogados se observa en hombres de la clase 3 en el grupo de edad de 16-40.

# %% [markdown]
# ##### Genero

# %%
# Crear el diccionario de mapeo
mapping = {'male': 1, 'female': 2}

# Asignar los valores a la nueva columna 'gender'
all_data['Gender'] = all_data['Sex'].map(mapping).fillna(3)

plt.figure(figsize = (15,4))

plt.subplot (1,3,1)
ax = sns.countplot(x = 'Gender', data = all_data, hue = 'Sex', palette="Set3")
plt.title('Number of passengers by Sex')
plt.ylabel('Number of passengers')

# calculate passengers for each category
labels = (all_data['Gender'].value_counts().index)
# add result numbers on barchart
for i, v in enumerate(labels):
    ax.text(i, v+10, str(v), horizontalalignment = 'center', size = 10, color = 'black')
    

plt.subplot (1,3,2)
sns.countplot( x = 'Pclass', data = all_data, hue = 'Sex', palette="Set3")
plt.title('Number of male/female passengers by class')
plt.ylabel('Number of passengers')
plt.legend( loc=(1.04,0))

plt.subplot (1,3,3)
sns.countplot( x = 'Family_size_group', data = all_data, hue = 'Sex', 
              order = all_data['Family_size_group'].value_counts().index , palette="Set3")
plt.title('Number of male/female passengers by family size')
plt.ylabel('Number of passengers')
plt.legend( loc=(1.04,0))
plt.tight_layout()

# %% [markdown]
# En general, había más hombres que mujeres a bordo, lo que es justo para cada clase de billete, pero en la 3ª clase el número de hombres era más del doble que el de mujeres. Casi 600 pasajeros varones viajaban sin familiares y sólo unas 200 mujeres, pero en las familias habituales y numerosas había un número ligeramente superior de pasajeras.

# %% [markdown]
# ##### Punto de embarque
#
# El Titanic tenía 3 puntos de embarque antes de que el buque iniciara su ruta hacia Nueva York:
#
# - Southampton
# - Cherburgo
# - Queenstown
#
# Algunos pasajeros podían dejar el Titanic en Cherbourg o Queenstown y evitar la catástrofe. Además, el punto de embarque podía influir en la tarifa del billete y en la ubicación en el barco.
#
# Puerto de embarque (**C** = Cherbourg; **Q** = Queenstown; **S** = Southampton)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Verifica si hay índices duplicados en el DataFrame
if all_data.index.duplicated().any():
    all_data = all_data.reset_index(drop=True)

# Verifica y convierte la columna 'Embarked' a tipo categórico si es necesario
if not pd.api.types.is_categorical_dtype(all_data['Embarked']):
    all_data['Embarked'] = pd.Categorical(all_data['Embarked'])

# Crea el gráfico de conteo
plt.figure(figsize=(8, 6))
palette = sns.cubehelix_palette(5, start=2)

# Crea el gráfico sin especificar el parámetro 'order'
ax1 = sns.countplot(data=all_data, x='Embarked', palette=palette)

# Añade el título y las etiquetas
plt.title('Número de pasajeros por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Número de pasajeros')

# Añade etiquetas a las barras
for p in ax1.patches:
    ax1.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                  ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1595781984.py:10: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not pd.api.types.is_categorical_dtype(all_data['Embarked']):
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1595781984.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.countplot(data=all_data, x='Embarked', palette=palette)
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1595781984.py:18: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   ax1 = sns.countplot(data=all_data, x='Embarked', palette=palette)

# %%
# Gráfico 2: Proporción de supervivientes y fallecidos por puerto de embarque
plt.figure(figsize=(8, 6))
surv_by_emb = all_data.groupby('Embarked')['Survived'].value_counts(normalize=True).unstack(fill_value=0).sort_index()
surv_by_emb.plot(kind='bar', stacked=True, color=["#3f3e6fd1", "#85c6a9"])
plt.title('Proportion of survived/drowned passengers by Embarked (train data)')
plt.xlabel('Embarked')
plt.ylabel('Proportion')
plt.legend(('Drowned', 'Survived'), loc=(1.04, 0))
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1601344379.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surv_by_emb = all_data.groupby('Embarked')['Survived'].value_counts(normalize=True).unstack(fill_value=0).sort_index()

# %%
# Gráfico 3: Proporción de clases sociales por puerto de embarque
plt.figure(figsize=(8, 6))
class_by_emb = all_data.groupby('Embarked')['Pclass'].value_counts(normalize=True).unstack(fill_value=0).sort_index()
class_by_emb.plot(kind='bar', stacked=True, color=['#eed4d0', '#cda0aa', '#a2708e'])
plt.title('Proportion of classes by Embarked')
plt.xlabel('Embarked')
plt.ylabel('Proportion')
plt.legend(('1st class', '2nd class', '3rd class'), loc=(1.04, 0))
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/955833181.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   class_by_emb = all_data.groupby('Embarked')['Pclass'].value_counts(normalize=True).unstack(fill_value=0).sort_index()

# %% [markdown]
# - La mayoría de los pasajeros (914) embarcaron en Southampton. También Southampton tiene la mayor proporción de pasajeros ahogados.
# - 270 pasajeros embarcaron en Cherburgo y más del 50% de ellos sobrevivieron (en el conjunto de datos de entrenamiento).
# - 123 pasajeros embarcaron en Queenstown, la gran mayoría de ellos en 3ª clase.

# %%
sns.catplot(x="Embarked", y="Fare", kind="violin", inner=None,
            data=all_data, height = 6, palette = palette, order = ['C', 'Q', 'S'])
plt.title('Distribution of Fare by Embarked')
plt.tight_layout()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/2406657033.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="Embarked", y="Fare", kind="violin", inner=None,
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/2406657033.py:1: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.catplot(x="Embarked", y="Fare", kind="violin", inner=None,

# %%
# Descriptive statistics:
pd.DataFrame(all_data.groupby('Embarked')['Fare'].describe())
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/1519355003.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   pd.DataFrame(all_data.groupby('Embarked')['Fare'].describe())
#           count       mean        std     min      25%       50%        75%  \
# Embarked
# C         270.0  62.336267  84.185996  4.0125  13.8583  28.51875  78.966675
# Q         123.0  12.409012  13.616133  6.7500   7.7500   7.75000  10.197900
# S         913.0  27.418824  37.096402  0.0000   8.0500  13.00000  27.750000
#
#                max
# Embarked
# C         512.3292
# Q          90.0000
# S         263.0000

# %% [markdown]
# - La mayor distribución de tarifas entre los pasajeros que embarcaron en Cherburgo. Es lógico: muchos pasajeros de primera clase embarcaron aquí, pero la proporción de pasajeros de tercera clase es bastante significativa.
# - La menor variación del precio de los pasajeros que embarcaron en q. Además, el precio medio de estos pasajeros es el más pequeño, creo que esto se debe al hecho de que se suponía que el trayecto era el más corto + casi todos los pasajeros de tercera clase.
#
# Comprobemos los valores NA de la variable Embarcado:

# %%
train_data[train_data['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# Estos dos pasajeros viajaron juntos (mismo número de billete). Para imputar los valores que faltan, podemos utilizar el valor de modo para los pasajeros con el valor de tarifa más cercano y Pclass.

# %% [markdown]
# ##### Tarifa

# %%
sns.catplot(x="Pclass", y="Fare", kind="swarm", data=all_data, palette=sns.cubehelix_palette(5, start = 3), height = 6)

plt.tight_layout()
# Out:
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/3626527308.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="Pclass", y="Fare", kind="swarm", data=all_data, palette=sns.cubehelix_palette(5, start = 3), height = 6)
# /var/folders/72/611d5rq92794d5dzdh80xgn40000gp/T/ipykernel_18816/3626527308.py:1: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.catplot(x="Pclass", y="Fare", kind="swarm", data=all_data, palette=sns.cubehelix_palette(5, start = 3), height = 6)
# /Users/lazaro.bustio/Gits/ciencia_datos/.venv/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 22.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Se observa que la distribución de los precios de la segunda y tercera clase es muy similar. La distribución de los precios de la primera clase es muy diferente, tiene una dispersión mayor y, por término medio, los precios son más altos.
#
# Añadamos colores a nuestros puntos para indicar el estado de supervivencia del pasajero (sólo habrá datos de la parte de entrenamiento del conjunto de datos):

# %%
sns.catplot(x="Pclass", y="Fare",  hue = "Survived", kind="swarm", data=all_data, 
                                    palette=["#3f3e6fd1", "#85c6a9"], height = 6)
plt.tight_layout()
# Out:
# /Users/lazaro.bustio/Gits/ciencia_datos/.venv/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/lazaro.bustio/Gits/ciencia_datos/.venv/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 47.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/lazaro.bustio/Gits/ciencia_datos/.venv/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 72.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Parece que cuanto más pagaba el pasajero, más posibilidades tenía de sobrevivir. ¿Qué pasa con la tarifa cero en primera clase? ¿Es un error?

# %%
all_data[all_data['Fare'] == min(all_data['Fare'])]
# Out:
#       PassengerId  Survived  Pclass                                   Name  \
# 179           180       0.0       3                    Leonard, Mr. Lionel
# 263           264       0.0       1                  Harrison, Mr. William
# 271           272       1.0       3           Tornquist, Mr. William Henry
# 277           278       0.0       2            Parkes, Mr. Francis "Frank"
# 302           303       0.0       3        Johnson, Mr. William Cahoone Jr
# 413           414       0.0       2         Cunningham, Mr. Alfred Fleming
# 466           467       0.0       2                  Campbell, Mr. William
# 481           482       0.0       2       Frost, Mr. Anthony Wood "Archie"
# 597           598       0.0       3                    Johnson, Mr. Alfred
# 633           634       0.0       1          Parr, Mr. William Henry Marsh
# 674           675       0.0       2             Watson, Mr. Ennis Hastings
# ...

# %% [markdown]
# Algunos de los pasajeros tienen billetes de "Línea", tal vez estaban involucrados de alguna manera en el Titanic, pero no eran la tripulación del barco. No creo que debamos cambiar estos precios, sino añadir una característica adicional para estos pasajeros.

# %% [markdown]
# #### Conclusión
#
# Se sabe que no había suficientes botes a bordo del Titanic para que todos los pasajeros pudieran ser evacuados. Tras estudiar la información sobre los pasajeros, se pueden hacer algunas suposiciones sobre quién tenía más posibilidades de sobrevivir en caso de naufragio, así como observaciones generales sobre los pasajeros.
#
# - Hay 891 pasajeros en el conjunto de datos del tren, 549 (61,6%) de ellos se ahogaron y sólo 342 (38,4%) sobrevivieron. Pero sabemos que los botes salvavidas (16 botes salvavidas de madera y cuatro plegables) podían transportar al 53% del total de pasajeros.
# - La edad de todos los pasajeros varía entre 0,17 y 80 años, con una media de 29,88 años. La media de edad de los pasajeros supervivientes es de 28,23 años, 2,39 menos que la media de edad de los pasajeros ahogados (los únicos de los que sabemos que sobrevivieron). Parece que la probabilidad de sobrevivir es ligeramente mayor entre los más jóvenes.
# - Explorando el título de los pasajeros, podemos ver que la mayor proporción de supervivientes se encuentra en el grupo de "Señora" - una mujer casada. Más del 80% se ahogó en el grupo del "Sr." y nadie sobrevivió entre el grupo del "Reverendo".
# - La mayoría de los pasajeros no tienen número de camarote. La mayor parte de los pasajeros con número de camarote conocido se encontraba en la cubierta "C" y tenía billete de 1ª clase. La cubierta 'C' es la quinta en porcentaje de supervivientes. El mayor porcentaje de supervivientes (entre los pasajeros con número de camarote conocido en el conjunto de datos de entrenamiento) correspondía a pasajeros de la cubierta "D". La cubierta 'A' era la más cercana a la cubierta con botes salvavidas, pero es la última en la tasa de supervivientes.
# - El tamaño de la familia a bordo también parece influir en las posibilidades de supervivencia: había dos familias numerosas de tamaños 8 y 11 y todos sus miembros del conjunto de datos de entrenamiento se ahogaron. Podemos observar que el porcentaje de supervivientes en las personas que tienen una familia de 2, 3, 4 personas es mayor que en los solteros, luego el porcentaje de supervivientes disminuye a medida que aumenta el tamaño de la familia.
# - La mayoría de los pasajeros del Titanic viajaban en tercera clase (709). La segunda clase es la más pequeña en cuanto al número de pasajeros. A pesar de los requisitos previamente identificados (de media, las personas mayores tienen más probabilidades de morir, y en la primera clase, la media de edad es más alta que en otras clases. Además, los pasajeros de la cubierta A, que consiste en un 100% de primera clase, tienen una gran proporción de pasajeros ahogados), la primera clase tiene el mayor número de supervivientes y la proporción de supervivientes dentro de la clase es la mayor.
# Los billetes de tercera clase tienen el mayor número de pasajeros ahogados, y la mayoría de los pasajeros de tercera clase se ahogaron.
# - Sin embargo, la mayoría de los pasajeros varones de primera clase se ahogaron, y las mujeres sobrevivieron casi todas. En la tercera clase, la mitad de las hembras sobrevivieron. En general había más hombres que mujeres a bordo, es justo para cada clase de billete, pero en la 3ª clase el número de hombres era más del doble que el de mujeres.
# Casi 600 pasajeros varones viajaban sin familiares y sólo unas 200 mujeres, pero en las familias habituales y numerosas había un número ligeramente superior de pasajeras.
# - La mayoría de los pasajeros (914) embarcaron en Southampton. Además, Southampton tiene la mayor proporción de pasajeros ahogados. 270 pasajeros embarcaron en Cherburgo y más del 50% de ellos sobrevivieron (en el conjunto de datos de entrenamiento). 123 de los pasajeros embarcaron en Queenstown y la gran mayoría de ellos son pasajeros de 3ª clase.
#
# Si se utiliza un planteamiento ingenuo y se considera todos los parámetros por separado, entonces las jóvenes pasajeras de primera clase con el título de "Señora" que tienen un número moderado de parientes a bordo, que pagaron una gran cantidad por el billete y embarcaron en Cherburgo tienen más posibilidades de sobrevivir. Sin duda, existe una relación entre las variables, y la supervivencia se vio influida no sólo por el título, o el billete, o la edad en sí, sino por una combinación de factores que en cierta medida están interrelacionados.
# Y es obvio que no existe ningún algoritmo que pueda predecir la tasa de supervivencia al 100% basándose en los factores de la ubicación del pasajero en el barco o su edad, ya que el factor humano y la emergencia imprevista intervinieron en el proceso de rescate.

# %% [markdown]
# #### Tratamiento de valores omitidos/valores atípicos/errores

# %% [markdown]
# #### Valores perdidos
#
# Los valores que faltan pueden deberse a diferentes motivos; existen tres mecanismos principales:
#
# - Missing Completely at Random (MCAR) - no hay relación entre la falta de datos y ningún valor, observado o faltante.
# - Falta al azar (MAR): existe una relación sistemática entre la propensión de los valores que faltan y los datos observados, pero no los que faltan.
# - Falta no aleatoria (MNAR): existe una relación entre la propensión de un valor a faltar y sus valores.
#
# Dependiendo de las razones por las que faltan valores, debemos actuar de forma diferente con la imputación de datos. No es fácil decir con seguridad qué tipo de valores faltantes tenemos, pero podemos hacer algunas suposiciones.
#
# Por ejemplo, basándonos en el hecho de que entre los pasajeros sin cabina especificada, el porcentaje de ahogados es mayor, podríamos pensar que la presencia de esta información nos dice algo (MAR). Falta información sobre la cabina de un número muy elevado de pasajeros (687 NA en el conjunto de datos de entrenamiento y 327 en el conjunto de datos de prueba). He leído sobre las suposiciones de que esta información se recogió de las palabras de los pasajeros supervivientes. Si este es el caso, entonces la presencia o ausencia de datos es en sí misma una información importante.
# Para conservar una posible información, podemos añadir una bandera separada que indique que la cabina del pasajero es desconocida. Yo utilizo el camarote para determinar la cubierta del pasajero; para aquellos que no dispongan de la información, añadiré la bandera "U". No tengo previsto utilizar el camarote en sí.
#
# La edad puede ser una situación similar (hay mayor porcentaje de pasajeros que sobrevivieron entre los pasajeros con edad no NA), así que añadiré una bandera de que la edad no está especificada ('Age_NA') antes de insertar los valores supuestos en la variable edad.
#
# Hay una tabla de valores perdidos:

# %%
# check data for NA values
train_NA = train_data.isna().sum()
test_NA = test_data.isna().sum()
pd.concat([train_NA, test_NA], axis=1, sort = False, keys = ['Train NA', 'Test NA'])
# Out:
#              Train NA  Test NA
# PassengerId         0      0.0
# Survived            0      NaN
# Pclass              0      0.0
# Name                0      0.0
# Sex                 0      0.0
# Age               177     86.0
# SibSp               0      0.0
# Parch               0      0.0
# Ticket              0      0.0
# Fare                0      1.0
# Cabin             687    327.0
# Embarked            2      0.0

# %% [markdown]
# Con `sns.heatmap` podemos visualizar los valores que faltan:

# %%
plt.figure(figsize = (16, 7))

plt.subplot(1,2,1)
sns.heatmap(train_data.isnull(), cbar=False)
plt.xticks(rotation = 35,     horizontalalignment='right',
    fontweight='light'  )
plt.title('Training dataset missing values')

plt.subplot(1,2,2)
sns.heatmap(test_data.isnull(), cbar=False)
plt.xticks(rotation=35,     horizontalalignment='right',
    fontweight='light'  )
plt.title('Test dataset missing values')

plt.tight_layout()

# %% [markdown]
# #### Edad
#
# En primer lugar, añado la variable Age_NA que indica que no hay edad en los datos originales.
# En segundo lugar, imputaré la mediana de edad calculada dentro de cada grupo Pclass + Sex + Title_category. Para ello, extraigo el título de la variable Nombre y lo asigno al diccionario de categorías de títulos.

# %%
import pandas as pd

# Suponiendo que los dataframes ya están cargados: train_data y test_data

# Crear una columna de título en ambos dataframes
def extract_title(name):
    return name.split(',')[1].split('.')[0].strip()

train_data['Title_category'] = train_data['Name'].apply(extract_title)
test_data['Title_category'] = test_data['Name'].apply(extract_title)

# Normalizar los títulos
title_dict = {  
    'Mr': 'Mr',
    'Mrs': 'Mrs',
    'Miss': 'Miss',
    'Master': 'Master',              
    'Ms': 'Miss',
    'Mme': 'Mrs',
    'Mlle': 'Miss',
    'Capt': 'military',
    'Col': 'military',
    'Major': 'military',
    'Dr': 'Dr',
    'Rev': 'Rev',                  
    'Sir': 'honor',
    'the Countess': 'honor',
    'Lady': 'honor',
    'Jonkheer': 'honor',
    'Don': 'honor',
    'Dona': 'honor'
}

train_data['Title_category'] = train_data['Title_category'].map(title_dict).fillna('unknown')
test_data['Title_category'] = test_data['Title_category'].map(title_dict).fillna('unknown')

# Calcular la mediana de 'Age' en 'train_data' por grupo 'Pclass', 'Sex', y 'Title_category'
median_age = train_data.groupby(['Pclass', 'Sex', 'Title_category'])['Age'].median()

# Imputar valores faltantes en 'Age' en 'train_data'
def impute_age(row):
    if pd.isnull(row['Age']):
        # Usar la mediana calculada en train_data
        return median_age.get((row['Pclass'], row['Sex'], row['Title_category']), pd.NA)
    else:
        return row['Age']

train_data['Age'] = train_data.apply(impute_age, axis=1)

# Imputar valores faltantes en 'Age' en 'test_data' usando la mediana calculada en train_data
def impute_age_test(row):
    if pd.isnull(row['Age']):
        # Usar la mediana calculada en train_data
        return median_age.get((row['Pclass'], row['Sex'], row['Title_category']), pd.NA)
    else:
        return row['Age']

test_data['Age'] = test_data.apply(impute_age_test, axis=1)

# Verificar la imputación en ambos dataframes
print("Faltantes en train_data:", train_data['Age'].isnull().sum())
print("Faltantes en test_data:", test_data['Age'].isnull().sum())
# Out:
# Faltantes en train_data: 0
# Faltantes en test_data: 0

# %% [markdown]
# #### Embarcado
#
# Faltan dos valores de Embarcado. Ambos pasajeros tienen un número de billete = 113572 (y el mismo número de cabina), por lo que viajaron juntos. Voy a imputar valores con valor mode para pasajeros de la misma clase en grupo de tarifa similar (77-82), porque la tarifa debe depender de la clase y la duración del viaje (que depende del lugar de embarque).

# %%
train_data[train_data['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Title_category
# 61   female  38.0      0      0  113572  80.0   B28      NaN           Miss
# 829  female  62.0      0      0  113572  80.0   B28      NaN            Mrs

# %%
mode_emb = train_data[(train_data['Fare'] > 77) & (train_data['Fare'] < 82)& (train_data['Pclass']==1)]['Embarked'].mode()
train_data.loc[train_data['Embarked'].isna(), 'Embarked'] = mode_emb[0]

# %% [markdown]
# ### Tarifa
#
# Sólo falta un valor de tarifa. Rellenaré NA con la mediana de la tarifa calculada dentro del mismo grupo Pclass + Sex + Title_category + Parch

# %%
import pandas as pd

# Supongamos que los dataframes ya están cargados: train_data y test_data

# Imputar los valores faltantes en 'Fare' en 'test_data' usando la mediana calculada en train_data
test_data['Fare'] = test_data.groupby(['Pclass', 'Sex', 'Title_category', 'Parch'])['Fare'].transform(lambda x: x.fillna(x.median()))

# Verificar la imputación
print("Faltantes en test_data después de imputar 'Fare':", test_data['Fare'].isnull().sum())
# Out:
# Faltantes en test_data después de imputar 'Fare': 0

# %% [markdown]
# #### Ingeniería de características
#
# A partir de 11 variables, generaré 31 características para cada pasajero.
# Tenemos que transformar las variables categóricas en números, porque la mayoría de los modelos sólo aceptan números como entrada. Utilizaré las siguientes formas de hacerlo:
#
# 1. Variables ficticias: una variable numérica utilizada para representar subgrupos de la muestra en su estudio. Toma sólo el valor 0 ó 1 para indicar la ausencia o presencia de alguna característica. Este método es muy adecuado para variables categóricas nominales, que no tienen un orden intrínseco en sus categorías.
#
# 2. Reemplazar valores de cadena por números - adecuado para variables ordinales (como la clase de billete de pasajero) o si sólo tenemos dos valores posibles (En este conjunto de datos podemos implementarlo a Sexo, por ejemplo).
#
# Características:
#
# - **Cubierta** (8 características) - Del número del camarote podemos extraer la primera letra, que nos indicará la ubicación del camarote en el barco (Cubierta). Si no hay número de Caín, el valor será **U** - desconocido. Utilizando la función get_dummies, lo convierto en 8 características ficticias con el prefijo **deck**.
# - **Title_category** (8 características) - Ya hemos creado la variable **Title_category** en la parte de imputación de faltas. Utilizando la función get_dummies, la convierto en 8 variables ficticias con el prefijo **title**.
# - **Family_size_group** (4 características) - Calculo **Family_size** resumiendo las variables **SibSp** y **Parch** y añadiendo 1. Luego creo **Family_size**. Luego creo **Family_size_group** (4 valores posibles) basado en el tamaño de la familia. Utilizando la función get_dummies, lo convierto en 8 características ficticias con el prefijo **family**.
# - **Age_NA** (1 característica) - Creamos esta variable durante el proceso de imputación de faltas.
# - Tarifa_cero** (1 característica) - Marca a las personas con tarifa cero, ya que pueden estar relacionadas con la White Star Line.
# - Embarcado** (3 características) - Utilizando la función get_dummies, convierto la variable **Embarcado** en 3 características ficticias con el prefijo **embarcado**.
# - Sexo (1 característica): como sólo tenemos 2 valores posibles, la convierto en una característica binaria: **1** si es mujer, **0** si es hombre.
# - Edad (1 característica): ya es numérica (continua).
# - Fare (1 característica) - ya numérica (continua).
# - Pclass (1 característica) - ya numérica (variable categórica ordinal).
# - SibSp (1 característica): como ya utilizamos el tamaño de la familia, convierto **SibSp** en una característica binaria: **1** si hay hermanos / cónyuges a bordo del Titanic, **0** si no los hay.
# - **Parch** (1 característica) - como ya usamos el tamaño de la familia, convierto **Parch** en una característica binaria - **1** si hay padres / hijos a bordo del Titanic, **0** si no.

# %%
def feature_generator (data, train = False):
    
    features_data = data
    
    # Deck
    # Extract deck letter from cabin number
    features_data['deck'] = features_data['Cabin'].str.split('', expand = True)[1]
    # If cabin is NA - deck = U
    features_data.loc[features_data['deck'].isna(), 'deck'] = 'U'
    # If cabin is T - change to A (see EDA)
    features_data.loc[features_data['deck'] == 'T', 'deck'] = 'A'
    # Create dummy variables with prefix 'deck'
    features_data = pd.concat([features_data,
                               pd.get_dummies(features_data['deck'], prefix = 'deck')], 
                               axis=1)
    
    
    # titles dummy
    features_data = pd.concat([features_data, 
                               pd.get_dummies(features_data['Title_category'],
                                              prefix = 'title')], axis=1)

    # family size
    features_data['Family_size'] = features_data['SibSp'] + features_data['Parch'] + 1
    features_data['Family_size_group'] = features_data['Family_size'].map(
                                            lambda x: 'f_single' if x == 1 
                                                    else ('f_usual' if 5 > x >= 2 
                                                          else ('f_big' if 8 > x >= 5 
                                                               else 'f_large' )))
    features_data = pd.concat([features_data, 
                               pd.get_dummies(features_data['Family_size_group'], 
                                              prefix = 'family')], axis=1)     
    
    
    # Sex to number
    features_data['Sex'] = features_data['Sex'].map({'female': 1, 'male': 0}).astype(int)
    
    # embarked dummy
    features_data = pd.concat([features_data, 
                               pd.get_dummies(features_data['Embarked'], 
                                              prefix = 'embarked')], axis=1)
    
    # zero fare feature
    features_data['zero_fare'] = features_data['Fare'].map(lambda x: 1 if x == 0 else (0))
    
    # from numeric to categorical
    features_data['SibSp'] = features_data['SibSp'].map(lambda x: 1 if x > 0 else (0))
    features_data['Parch'] = features_data['Parch'].map(lambda x: 1 if x > 0 else (0))
    
    # delete variables we are not going to use anymore
    del features_data['PassengerId']
    del features_data['Ticket']
    del features_data['Cabin']
    del features_data['deck']    
    del features_data['Title_category']
    del features_data['Name']
    del features_data['Family_size']
    del features_data['Family_size_group'] 
    del features_data['Embarked']    
    
    return features_data

# %%
# Generate features from training dataset
all_train_features = feature_generator(train_data)
# Generate features from test dataset
all_test_features = feature_generator(test_data)

# %%
all_train_features
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  deck_A  deck_B  \
# 0           0       3    0  22.0      1      0   7.2500   False   False
# 1           1       1    1  38.0      1      0  71.2833   False   False
# 2           1       3    1  26.0      0      0   7.9250   False   False
# 3           1       1    1  35.0      1      0  53.1000   False   False
# 4           0       3    0  35.0      0      0   8.0500   False   False
# ..        ...     ...  ...   ...    ...    ...      ...     ...     ...
# 886         0       2    0  27.0      0      0  13.0000   False   False
# 887         1       1    1  19.0      0      0  30.0000   False    True
# 888         0       3    1  18.0      1      1  23.4500   False   False
# 889         1       1    0  26.0      0      0  30.0000   False   False
# 890         0       3    0  32.0      0      0   7.7500   False   False
#
#      deck_C  ...  title_honor  title_military  family_f_big  family_f_large  \
# ...

# %% [markdown]
# #### Correlación
#
# La correlación indica lo cerca que están dos variables de tener una relación lineal entre sí. Las características con alta correlación son más linealmente dependientes y, por tanto, tienen casi el mismo efecto sobre la variable dependiente. Por lo tanto, cuando dos características tienen una alta correlación, podemos eliminar una de las dos características.

# %%
plt.figure(figsize=(12,10))
cor = all_train_features.corr()
sns.heatmap(cor)
# Out:
# <Axes: >

# %% [markdown]
# ## Tarea

# %% [markdown]
# 1. Ejercicio
#
#     Eres un analista de datos en una empresa de comercio electrónico y se te ha proporcionado un archivo CSV llamado “datos_ventas.csv” que contiene datos de ventas de diferentes productos. Tu objetivo es realizar un análisis más completo y detallado de las ventas utilizando Python y las bibliotecas estudiadas hasta el momento:
#
# 2.	Instrucciones:
#
# - Cargar los datos desde el archivo CSV y almacenarlos en un DataFrame llamado ventas.
# - Calcular y mostrar el resumen estadístico completo del DataFrame, incluyendo medidas de tendencia central, dispersión y forma.
# - Realizar un análisis por categoría de productos. Para cada categoría, calcular y mostrar:
#     - La cantidad total de productos vendidos.
#     - El precio promedio de venta.
#     - La cantidad máxima y mínima de productos vendidos.
#     - El rango intercuartil (IQR) de los precios .
# - Calcular y mostrar la matriz de correlación entre las columnas “cantidad” y “precio”, así como también visualizarla mediante un mapa de calor .
# - Identificar los productos con ventas atípicas (outliers) en función de la cantidad vendida. Mostrar los nombres de los productos y las cantidades correspondientes.
# - Calcular y mostrar el porcentaje de ventas acumuladas por categoría. Ordenar las categorías de mayor a menor por su porcentaje de ventas acumuladas.
# - Realizar un análisis temporal de las ventas. Agrupar las ventas por mes y mostrar:
#     - La cantidad total de productos vendidos en cada mes.
#     - El precio promedio de venta en cada mes.
#     - El mes con el mayor y menor monto total de ventas.
# - Exportar los resultados obtenidos en los pasos 3, 4, 5, 6 y 7 a un nuevo archivo CSV llamado “resultados_ventas.csv”.
#
# Sugerencia: Utiliza las funciones y métodos de la biblioteca Pandas para realizar las operaciones necesarias.

# %% [markdown]
# ### Datos sintéticos
#
# Primero se deben generar datos sintéticos para este ejercicio por si no se tienen.

# %% [markdown]
# Se importan las librerías adecuadas

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# %%
# Lista de productos y categorías
productos = ["Producto A", "Producto B", "Producto C"]
categorias = ["Categoria 1", "Categoria 2"]

# %%
# Generar datos aleatorios
datos = []
fecha_actual = datetime.now().date()
for _ in range(100):
	producto = random.choice(productos)
	categoria = random.choice(categorias)
	fecha = fecha_actual - timedelta(days=random.randint(0, 365))
	cantidad = random.randint(1, 20)
	precio = round(random.uniform(10, 50), 2)
	datos.append([producto, categoria, fecha, cantidad, precio])

# %%
# Crear DataFrame y guardar en archivo CSV
df = pd.DataFrame(datos, columns=["Producto", "Categoria", "Fecha", 
"Cantidad", "Precio"])
df.to_csv("datos_ventas.csv", index=False)

# %% [markdown]
# ### Solución de la tarea

# %%
# Importar las librerias que se usarán
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# a)	Cargar los datos desde el archivo CSV y almacenarlos en un DataFrame llamado ventas.

# %%
# Paso 1: Cargar los datos desde el archivo CSV y almacenarlos en un DataFrame llamado "ventas"
ventas = pd.read_csv('datos_ventas.csv')

# %% [markdown]
# b)	Calcular y mostrar el resumen estadístico completo del DataFrame, incluyendo medidas de tendencia central, dispersión y forma.

# %%
# Paso 2: Calcular y mostrar el resumen estadístico completo del DataFrame
resumen_estadistico = ventas.describe()
print(resumen_estadistico)
# Out:
#          Cantidad      Precio
# count  100.000000  100.000000
# mean     9.570000   28.888100
# std      5.876258   11.189085
# min      1.000000   10.660000
# 25%      5.000000   19.747500
# 50%      9.000000   27.250000
# 75%     15.000000   36.842500
# max     20.000000   49.790000

# %% [markdown]
# c)	Realizar un análisis por categoría de productos. Para cada categoría, calcular y mostrar:

# %%
# Paso 3: Realizar un análisis por categoría de productos
analisis_categorias = ventas.groupby('Categoria').agg({
    'Cantidad': 'sum',
    'Precio': ['mean', 'max', 'min'],
})
print(analisis_categorias)
# Out:
#             Cantidad     Precio
#                  sum       mean    max    min
# Categoria
# Categoria 1      462  28.524783  49.79  10.66
# Categoria 2      495  29.197593  48.17  11.58

# %% [markdown]
# d)	Calcular y mostrar la matriz de correlación entre las columnas “cantidad” y “precio”, así como también visualizarla mediante un mapa de calor.

# %%
# Paso 4: Calcular y mostrar la matriz de correlación entre las columnas "cantidad" y "precio"
matriz_correlacion = ventas[['Cantidad', 'Precio']].corr()
print(matriz_correlacion)

# Visualización de la matriz de correlación mediante un mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()
# Out:
#           Cantidad    Precio
# Cantidad  1.000000  0.018435
# Precio    0.018435  1.000000

# %% [markdown]
# e)	Identificar los productos con ventas atípicas (outliers) en función de la cantidad vendida. Mostrar los nombres de los productos y las cantidades correspondientes.

# %%
# Paso 5: Identificar los productos con ventas atípicas (outliers) en función de la cantidad vendida
q1 = ventas['Cantidad'].quantile(0.25)
q3 = ventas['Cantidad'].quantile(0.75)
iqr = q3 - q1
umbral_superior = q3 + 1.5 * iqr
outliers_cantidad = ventas[ventas['Cantidad'] > umbral_superior][['Producto', 'Cantidad']]
print(outliers_cantidad)
# Out:
# Empty DataFrame
# Columns: [Producto, Cantidad]
# Index: []

# %% [markdown]
# f)	Calcular y mostrar el porcentaje de ventas acumuladas por categoría. Ordenar las categorías de mayor a menor por su porcentaje de ventas acumuladas.

# %%
# Paso 6: Calcular y mostrar el porcentaje de ventas acumuladas por categoría
ventas_por_categoria = ventas.groupby('Categoria')['Cantidad'].sum()
porcentaje_ventas_acumuladas = ventas_por_categoria / ventas['Cantidad'].sum() * 100
porcentaje_ventas_acumuladas = porcentaje_ventas_acumuladas.sort_values(ascending=False)
print(porcentaje_ventas_acumuladas)
# Out:
# Categoria
# Categoria 2    51.724138
# Categoria 1    48.275862
# Name: Cantidad, dtype: float64

# %% [markdown]
# g)	Realizar un análisis temporal de las ventas.

# %%
# Paso 7: Realizar un análisis temporal de las ventas
ventas['mes'] = pd.to_datetime(ventas['Fecha']).dt.month
analisis_temporal = ventas.groupby('mes').agg({
    'Cantidad': 'sum',
    'Precio': 'mean',
})
mes_mayor_monto_ventas = analisis_temporal['Precio'].idxmax()
mes_menor_monto_ventas = analisis_temporal['Precio'].idxmin()
print(analisis_temporal)
print("Mes con el mayor monto total de ventas:", mes_mayor_monto_ventas)
print("Mes con el menor monto total de ventas:", mes_menor_monto_ventas)
# Out:
#      Cantidad     Precio
# mes
# 1         147  33.699231
# 2          92  28.065556
# 3          92  28.308000
# 4          40  29.124000
# 5          53  26.615000
# 6          89  30.208750
# 7          47  33.032000
# 8          63  32.165000
# 9          31  26.011667
# 10         91  33.404286
# 11         72  21.668182
# 12        140  27.262143
# Mes con el mayor monto total de ventas: 1
# Mes con el menor monto total de ventas: 11

# %% [markdown]
# h)	Exportar los resultados obtenidos en los pasos 3, 4, 5, 6 y 7 a un nuevo archivo CSV llamado “resultados_ventas.csv”.

# %%
# Paso 8: Exportar los resultados obtenidos a un nuevo archivo CSV llamado "resultados_ventas.csv"
resumen_estadistico.to_csv('resultados_ventas.csv', index=False, header=True)
analisis_categorias.to_csv('resultados_ventas.csv', mode='a', index=True, header=True)
matriz_correlacion.to_csv('resultados_ventas.csv', mode='a', index=True, header=True)
outliers_cantidad.to_csv('resultados_ventas.csv', mode='a', index=False, header=True)
porcentaje_ventas_acumuladas.to_csv('resultados_ventas.csv', mode='a', index=True, header=True)
analisis_temporal.to_csv('resultados_ventas.csv', mode='a', index=True, header=True)
