# %% [markdown]
# # Actividad 08: Visualización de datos

# %% [markdown]
# ## Ejercicio de clase

# %% [markdown]
# Primero, se deben instalar las librerías que se van a usar

# %%
# Instalar librerías (en Python se llaman módulos)
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install gapminder
# %pip install plotly
# %pip install nbformat
# %pip install chart-studio
# %pip install statsmodels
# %pip install networkx
# %pip install pyecharts
# %pip install matplotlib-venn
# %pip install wordcloud
# %pip install folium
# %pip install geopandas
# %pip install geopy
# Out:
# Requirement already satisfied: pandas in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas) (1.25.0)
# Requirement already satisfied: six>=1.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (1.25.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (3.7.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gapminder in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from gapminder) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas->gapminder) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas->gapminder) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas->gapminder) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas->gapminder) (1.25.0)
# Requirement already satisfied: six>=1.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->gapminder) (1.16.0)
# Requirement already satisfied: plotly in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from plotly) (23.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nbformat in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (5.9.0)
# Requirement already satisfied: fastjsonschema in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from nbformat) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from nbformat) (4.18.0)
# Requirement already satisfied: jupyter-core in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from nbformat) (5.3.1)
# Requirement already satisfied: traitlets>=5.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from nbformat) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.6.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.29.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.8.8)
# Requirement already satisfied: platformdirs>=2.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jupyter-core->nbformat) (3.8.0)
# Requirement already satisfied: pywin32>=300 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jupyter-core->nbformat) (306)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: chart-studio in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (1.1.0)
# Requirement already satisfied: plotly in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from chart-studio) (5.15.0)
# Requirement already satisfied: requests in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from chart-studio) (2.31.0)
# Requirement already satisfied: retrying>=1.3.3 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from chart-studio) (1.3.4)
# Requirement already satisfied: six in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from chart-studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from plotly->chart-studio) (8.2.2)
# Requirement already satisfied: packaging in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from plotly->chart-studio) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->chart-studio) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->chart-studio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->chart-studio) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->chart-studio) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from statsmodels) (1.25.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from statsmodels) (1.11.1)
# Requirement already satisfied: pandas>=1.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from statsmodels) (2.0.3)
# Requirement already satisfied: patsy>=0.5.2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: networkx in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (3.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pyecharts in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (2.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: jinja2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pyecharts) (3.1.2)
# Requirement already satisfied: prettytable in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pyecharts) (3.8.0)
# Requirement already satisfied: simplejson in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pyecharts) (3.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jinja2->pyecharts) (2.1.3)
# Requirement already satisfied: wcwidth in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from prettytable->pyecharts) (0.2.6)
# Requirement already satisfied: matplotlib-venn in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (0.11.9)
# Requirement already satisfied: matplotlib in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib-venn) (3.7.2)
# Requirement already satisfied: numpy in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib-venn) (1.25.0)
# Requirement already satisfied: scipy in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib-venn) (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->matplotlib-venn) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wordcloud in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from wordcloud) (1.25.0)
# Requirement already satisfied: pillow in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from wordcloud) (10.0.0)
# Requirement already satisfied: matplotlib in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: folium in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from folium) (1.25.0)
# Requirement already satisfied: requests in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->folium) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->folium) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from requests->folium) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopandas in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from fiona>=1.8.19->geopandas) (8.1.4)
# Requirement already satisfied: click-plugins>=1.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from pandas>=1.1.0->geopandas) (1.25.0)
# Requirement already satisfied: colorama in d:\projects\vscode\ciencia_datos\.venv\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Collecting geopy
#   Downloading geopy-2.3.0-py3-none-any.whl (119 kB)
#                                               0.0/119.8 kB ? eta -:--:--
#      ---------                               30.7/119.8 kB 1.4 MB/s eta 0:00:01
#      ------------------                    61.4/119.8 kB 656.4 kB/s eta 0:00:01
#      -------------------------------------- 119.8/119.8 kB 1.0 MB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#                                               0.0/40.3 kB ? eta -:--:--
#      ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Gráficos

# %%
# Area
import numpy as np # libreria para el trabajo con matrices
import matplotlib.pyplot as plt # libreria para la visualizacion
import random # libreria par el manejo de numeros aleatorios

rng = 10
x = range(0, rng)
y = list() # lluvia en el 2019
z = list() # lluvia en el 2020

for i in range(rng):
  y.append(random.randint(0, 9))
  z.append(random.randint(0,15))

# Encabezados y personalizacion general del grafico
plt.title("Precipitaciones por año")

# Dibujos de los graficos
plt.fill_between(x, z)
plt.fill_between(x, y)

# Personalizaciones finas
# Personalizando X
plt.xlabel("x label")
plt.tick_params(axis='x', colors='red', direction='out', length=7, width=2)
plt.xticks(x, ["Ene", "Feb", "Mar", "Abr", "May", "Jun", "Jul", "Ago", "Sept", "Oct"])

# Personalizando Y
plt.ylabel("y label")

# Mostrar el resultado
plt.show()

# %%
# Barplot

# Importar las librerías necesarias
import numpy as np
import matplotlib.pyplot as plt

# Crear un conjunto de datos aleatorio
height = [3, 12, 5, 18, 45]  # Altura de las barras
bars = ('A', 'B', 'C', 'D', 'E')  # Etiquetas de las barras
y_pos = np.arange(len(bars))  # Posiciones en el eje y

# Crear las barras
plt.bar(y_pos, height)

# Asignar etiquetas en el eje x
plt.xticks(y_pos, bars)

# Mostrar el gráfico
plt.show()

# %%
#Boxplot

# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

sns.boxplot( x=df["species"], y=df["sepal_length"] )
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
# bubble graph

# Importar las librerías necesarias
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder  # Conjunto de datos

# Cargar el conjunto de datos
data = gapminder.loc[gapminder.year == 2007]  # Filtrar datos para el año 2007

# Utilizar la función scatterplot para construir el mapa de burbujas
sns.scatterplot(data=data, x="gdpPercap", y="lifeExp", size="pop", legend=False, sizes=(20, 2000))

# Mostrar el gráfico
plt.show()

# %%
# Bubble map
# Importar la librería necesaria
import plotly.express as px

# Cargar el conjunto de datos y filtrar para el año 2007
df = px.data.gapminder().query("year==2007")

# Crear la figura del gráfico de dispersión geográfico
fig = px.scatter_geo(df, locations="iso_alpha", color="continent",
                     hover_name="country", size="pop",
                     projection="natural earth")

# Mostrar el gráfico
fig.show()

# %%
# Bullet graph

# Importar la librería necesaria
import plotly.graph_objects as go

# Crear una figura vacía
fig = go.Figure()

# Añadir el primer indicador (Revenue)
fig.add_trace(go.Indicator(
    mode = "number+gauge+delta", value = 180,  # Configurar el valor y el modo del indicador
    delta = {'reference': 200},  # Configurar la referencia para el delta
    domain = {'x': [0.25, 1], 'y': [0.08, 0.25]},  # Configurar la posición en el gráfico
    title = {'text': "Revenue"},  # Configurar el título del indicador
    gauge = {
        'shape': "bullet",  # Configurar la forma del indicador
        'axis': {'range': [None, 300]},  # Configurar el rango del eje
        'threshold': {
            'line': {'color': "black", 'width': 2},  # Configurar la línea del umbral
            'thickness': 0.75,  # Configurar el grosor del umbral
            'value': 170},  # Configurar el valor del umbral
        'steps': [
            {'range': [0, 150], 'color': "gray"},  # Configurar los rangos y colores de los pasos
            {'range': [150, 250], 'color': "lightgray"}],  # Configurar los rangos y colores de los pasos
        'bar': {'color': "black"}}))  # Configurar el color de la barra

# Añadir el segundo indicador (Profit)
fig.add_trace(go.Indicator(
    mode = "number+gauge+delta", value = 35,  # Configurar el valor y el modo del indicador
    delta = {'reference': 200},  # Configurar la referencia para el delta
    domain = {'x': [0.25, 1], 'y': [0.4, 0.6]},  # Configurar la posición en el gráfico
    title = {'text': "Profit"},  # Configurar el título del indicador
    gauge = {
        'shape': "bullet",  # Configurar la forma del indicador
        'axis': {'range': [None, 100]},  # Configurar el rango del eje
        'threshold': {
            'line': {'color': "black", 'width': 2},  # Configurar la línea del umbral
            'thickness': 0.75,  # Configurar el grosor del umbral
            'value': 50},  # Configurar el valor del umbral
        'steps': [
            {'range': [0, 25], 'color': "gray"},  # Configurar los rangos y colores de los pasos
            {'range': [25, 75], 'color': "lightgray"}],  # Configurar los rangos y colores de los pasos
        'bar': {'color': "black"}}))  # Configurar el color de la barra

# Añadir el tercer indicador (Satisfaction)
fig.add_trace(go.Indicator(
    mode = "number+gauge+delta", value = 220,  # Configurar el valor y el modo del indicador
    delta = {'reference': 200},  # Configurar la referencia para el delta
    domain = {'x': [0.25, 1], 'y': [0.7, 0.9]},  # Configurar la posición en el gráfico
    title = {'text' :"Satisfaction"},  # Configurar el título del indicador
    gauge = {
        'shape': "bullet",  # Configurar la forma del indicador
        'axis': {'range': [None, 300]},  # Configurar el rango del eje
        'threshold': {
            'line': {'color': "black", 'width': 2},  # Configurar la línea del umbral
            'thickness': 0.75,  # Configurar el grosor del umbral
            'value': 210},  # Configurar el valor del umbral
        'steps': [
            {'range': [0, 150], 'color': "gray"},  # Configurar los rangos y colores de los pasos
            {'range': [150, 250], 'color': "lightgray"}],  # Configurar los rangos y colores de los pasos
        'bar': {'color': "black"}}))  # Configurar el color de la barra

# Actualizar el diseño de la figura
fig.update_layout(height = 400 , margin = {'t':0, 'b':0, 'l':0})

# Mostrar el gráfico
fig.show()

# %%
# Chordgraph
# Importar las librerías necesarias
import chart_studio.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go

# Crear los datos de la tabla
data = [['', 'Emma', 'Isabella', 'Ava', 'Olivia', 'Sophia', 'row-sum'],
        ['Emma', 16, 3, 28, 0, 18, 65],
        ['Isabella', 18, 0, 12, 5, 29, 64],
        ['Ava', 9, 11, 17, 27, 0, 64],
        ['Olivia', 19, 0, 31, 11, 12, 73],
        ['Sophia', 23, 17, 10, 0, 34, 84]]

# Crear la tabla utilizando create_table de figure_factory
table = ff.create_table(data, index=True)

# Mostrar la tabla utilizando iplot de plotly
py.iplot(table, filename='Data-Table')

# %%
# Candle plot

# Importar la librería necesaria
import plotly.graph_objects as go
from datetime import datetime

# Datos de los precios de una acción
open_data = [33.0, 33.3, 33.5, 33.0, 34.1]
high_data = [33.1, 33.3, 33.6, 33.2, 34.8]
low_data = [32.7, 32.7, 32.8, 32.6, 32.8]
close_data = [33.0, 32.9, 33.3, 33.1, 33.1]

# Fechas correspondientes a los precios
dates = [datetime(year=2013, month=10, day=10),
         datetime(year=2013, month=11, day=10),
         datetime(year=2013, month=12, day=10),
         datetime(year=2014, month=1, day=10),
         datetime(year=2014, month=2, day=10)]

# Crear la figura del gráfico de velas (candlestick)
fig = go.Figure(data=[go.Candlestick(x=dates,
                       open=open_data, high=high_data,
                       low=low_data, close=close_data)])

# Mostrar el gráfico
fig.show()

# %%
# Density map
# Importar la librería necesaria
import seaborn as sns

# Cargar el conjunto de datos 'iris'
iris_df = sns.load_dataset('iris')

sns.kdeplot(iris_df["sepal_width"], fill = True)
sns.kdeplot(iris_df["sepal_length"], fill = True)
sns.kdeplot(iris_df["petal_length"], fill = True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
# Donut plot
# Importar la librería necesaria
import matplotlib.pyplot as plt

# Crear los datos
size_of_groups = [12, 11, 3, 30]

# Crear un gráfico de torta (pie plot)
plt.pie(size_of_groups)

# Agregar un círculo en el centro para convertirlo en un gráfico de dona
my_circle = plt.Circle((0, 0), 0.7, color='white')
p = plt.gcf()
p.gca().add_artist(my_circle)

# Mostrar el gráfico
plt.show()

# %%
# Errorbarplot
# Importar las librerías necesarias
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)

# Valores de error variables de ejemplo
yerr = 0.1 + 0.2*np.sqrt(x)
xerr = 0.1 + yerr

# Ejemplo básico utilizando la interfaz de pyplot
plt.figure()
plt.errorbar(x, y, xerr=0.2, yerr=0.4)
plt.title("Simplest errorbars, 0.2 in x, 0.4 in y")

# Cambiar a una interfaz orientada a objetos (OO) para ejercitar más características.
fig, axs = plt.subplots(nrows=2, ncols=2, sharex=True)
ax = axs[0,0]
ax.errorbar(x, y, yerr=yerr, fmt='o')
ax.set_title('Vert. symmetric')

# Reducir el número de marcas de los ejes en 4 subgráficos para evitar amontonamiento.
ax.locator_params(nbins=4)

ax = axs[0,1]
ax.errorbar(x, y, xerr=xerr, fmt='o')
ax.set_title('Hor. symmetric')

ax = axs[1,0]
ax.errorbar(x, y, yerr=[yerr, 2*yerr], xerr=[xerr, 2*xerr], fmt='--o')
ax.set_title('H, V asymmetric')

ax = axs[1,1]
ax.set_yscale('log')
# Aquí debemos asegurarnos de mantener todos los valores de y positivos:
ylower = np.maximum(1e-2, y - yerr)
yerr_lower = y - ylower

ax.errorbar(x, y, yerr=[yerr_lower, 2*yerr], xerr=xerr,
            fmt='o', ecolor='g', capthick=2)
ax.set_title('Mixed sym., log y')

fig.suptitle('Variable errorbars')

plt.show()

# %%
# Heatmap
# Importar las librerías necesarias
import seaborn as sns
import pandas as pd
import numpy as np

# Crear un conjunto de datos
df = pd.DataFrame(np.random.random((5,5)), columns=["a","b","c","d","e"])

# Mapa de calor por defecto
p1 = sns.heatmap(df)

# %%
# Histogram
# Importar las librerías necesarias
import seaborn as sns

# Cargar el conjunto de datos 'iris'
df = sns.load_dataset('iris')

# Graficar el histograma utilizando la función distplot
sns.distplot(a=df["sepal_length"], hist=True, kde=False, rug=False)
# Out:
# C:\Users\lbust\AppData\Local\Temp\ipykernel_18976\3997587434.py:9: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='sepal_length'>

# %%
iris_df["sepal_length"].hist()
plt.show()

# %%
# Lineplot
# se generan datos de manera aleatoria
values = np.cumsum(np.random.randn(100,1))
values1 = np.cumsum(np.random.randn(100,1))
values2 = np.cumsum(np.random.randn(100,1))

# se crea el grafico de lineas
plt.plot(values)
plt.plot(values1)
plt.plot(values2)

# se muestra el grafico
plt.show()

# %%
# Stackedbar

# Generar datos
height1 = [3, 12, 5, 18, 45]
height2 = [13, 112, 15, 118, 145]
bars = ["Clase A", "Clase B", "Clase C", "Clase D", "Clase E"]
y_pos = np.arange(len(bars))

# Crear el gráfico de barras
plt.bar(y_pos, height2)
plt.bar(y_pos, height1)

# personalizacion
plt.xticks(y_pos, bars)

# mostrar gráfico
plt.show()

# %%
# Marimekko graph
# Importar las librerías necesarias
import pandas as pd
from statsmodels.graphics.mosaicplot import mosaic
import pylab
from itertools import product
import numpy as np

# Crear los datos
rand = np.random.random
speaks_mul_foreign_languages = list(product(['male', 'female'], ['yes', 'no']))
index = pd.MultiIndex.from_tuples(speaks_mul_foreign_languages, names=['male', 'female'])
data = pd.Series(rand(4), index=index)

# Crear el gráfico de mosaico
mosaic(data, gap=0.01, title='Who knows multiple foreign languages? - Mosaic Chart')
pylab.show()

# %%
# Network graph
# Importar las librerías necesarias
import plotly.graph_objects as go
import networkx as nx

# Crear un grafo aleatorio
G = nx.random_geometric_graph(200, 0.125)

# Crear listas para las coordenadas de las aristas
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

# Crear la traza de las aristas
edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

# Crear listas para las coordenadas de los nodos
node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

# Crear la traza de los nodos
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# Calcular el número de conexiones de cada nodo
node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    node_text.append('# of connections: '+str(len(adjacencies[1])))

# Asignar los valores calculados a la traza de los nodos
node_trace.marker.color = node_adjacencies
node_trace.text = node_text

# Crear la figura con las trazas de las aristas y los nodos
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='<br>Network graph made with Python',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )

# Mostrar la figura
fig.show()

# %%
# Nightingale rose
import pandas as pd
from pyecharts.charts import Pie
from pyecharts import options as opts

# Preparar datos
provincias = ['Beijing', 'Shanghai', 'Heilongjiang', 'Jilin', 'Liaoning', 'Mongolia Interior',
              'Xinjiang', 'Tibet', 'Qinghai', 'Sichuan', 'Yunnan', 'Shaanxi', 'Chongqing',
              'Guizhou', 'Guangxi', 'Hainan', 'Macao', 'Hunan', 'Jiangxi', 'Fujian', 'Anhui',
              'Zhejiang', 'Jiangsu', 'Ningxia', 'Shanxi', 'Hebei', 'Tianjin']
num = [1, 1, 1, 17, 9, 22, 23, 42, 35, 7, 20, 21, 16, 24, 16, 21, 37, 12, 13, 14, 13, 7, 22, 8, 16, 13, 13]
color_series = ['#FAE927', '#E9E416', '#C9DA36', '#9ECB3C', '#6DBC49',
                '#37B44E', '#3DBA78', '#14ADCF', '#209AC9', '#1E91CA',
                '#2C6BA0', '#2B55A1', '#2D3D8E', '#44388E', '#6A368B'
                '#7D3990', '#A63F98', '#C31C88', '#D52178', '#D5225B',
                '#D02C2A', '#D44C2D', '#F57A34', '#FA8F2F', '#D99D21',
                '#CF7B25', '#CF7B25', '#CF7B25']

# Crear marco de datos
df = pd.DataFrame({'provincias': provincias, 'num': num})
# Orden descendiente
df.sort_values(by='num', ascending=False, inplace=True)

# Extraer datos
v = df['provincias'].values.tolist()
d = df['num'].values.tolist()

# Instanciar la clase Pie
pie1 = Pie(init_opts=opts.InitOpts(width='1350px', height='750px'))
# Establecer color
pie1.set_colors(color_series)
# Agregar datos, establecer el radio del gráfico circular, ya sea para mostrarlo como un gráfico ruiseñor
pie1.add("", [list(z) for z in zip(v, d)],
         radius=["30%", "135%"],
         center=["50%", "65%"],
         rosetype="area"
         )
# Establecer elementos de configuración global
pie1.set_global_opts(title_opts=opts.TitleOpts(title='ejemplo de gráfico de rosas'),
                     legend_opts=opts.LegendOpts(is_show=False),
                     toolbox_opts=opts.ToolboxOpts())

# Establecer elementos de configuración de la serie
pie1.set_series_opts(label_opts=opts.LabelOpts(is_show=True, position="inside", font_size=12,
                                               formatter="{b}: {c} day", font_style="italic",
                                               font_weight="bold", font_family="Microsoft YaHei"
                                               ),
                     )
# Generar documento html
pie1.render('Nightingale rose map.html')
# Out:
# 'd:\\Projects\\VSCode\\ciencia_datos\\Nightingale rose map.html'

# %%
# Olhc graph
import plotly.graph_objects as go
from datetime import datetime

# Datos de ejemplo
open_data = [33.0, 33.3, 33.5, 33.0, 34.1]
high_data = [33.1, 33.3, 33.6, 33.2, 34.8]
low_data = [32.7, 32.7, 32.8, 32.6, 32.8]
close_data = [33.0, 32.9, 33.3, 33.1, 33.1]
dates = [datetime(year=2013, month=10, day=10),
         datetime(year=2013, month=11, day=10),
         datetime(year=2013, month=12, day=10),
         datetime(year=2014, month=1, day=10),
         datetime(year=2014, month=2, day=10)]

# Crear figura con gráfico de velas
fig = go.Figure(data=[go.Ohlc(x=dates,
                              open=open_data, high=high_data,
                              low=low_data, close=close_data)])
fig.show()

# %%
# Parallel plots
import pandas
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

# Importar el dataset iris
import seaborn as sns
data = sns.load_dataset('iris')

# Crear el gráfico de coordenadas paralelas
parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
plt.show()

# %%
# Pie chart
import matplotlib.pyplot as plt

# Crear datos: un arreglo de valores
size_of_groups = [12, 11, 3, 30]

# Crear un gráfico de torta (pie chart)
plt.pie(size_of_groups)
plt.show()

# %%
# Radarchart
import plotly.graph_objects as go

# Definir las categorías
categories = ['processing cost', 'mechanical properties', 'chemical stability',
              'thermal stability', 'device integration']

# Crear una figura vacía
fig = go.Figure()

# Agregar la primera serie de datos al gráfico polar
fig.add_trace(go.Scatterpolar(
      r=[1, 5, 2, 2, 3],  # Valores para la primera serie de datos
      theta=categories,  # Categorías en el eje theta
      fill='toself',     # Rellenar el área entre las líneas
      name='Product A'   # Nombre de la primera serie de datos
))

# Agregar la segunda serie de datos al gráfico polar
fig.add_trace(go.Scatterpolar(
      r=[4, 3, 2.5, 1, 2],  # Valores para la segunda serie de datos
      theta=categories,     # Categorías en el eje theta
      fill='toself',        # Rellenar el área entre las líneas
      name='Product B'      # Nombre de la segunda serie de datos
))

# Actualizar la configuración del layout del gráfico
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 5]    # Rango del eje radial
    )),
  showlegend=False    # Ocultar la leyenda
)

# Mostrar el gráfico
fig.show()

# %%
# Radialbar plot
import matplotlib.pyplot as plt
from matplotlib import cm
from math import log10

# Etiquetas de los segmentos
labels = list("ABCDEFG")
# Datos para cada segmento
data = [21, 57, 88, 14, 76, 91, 26]
# Número de puntos de datos
n = len(data)
# Encontrar el valor máximo para el anillo completo
k = 10 ** int(log10(max(data)))
m = k * (1 + max(data) // k)

# Radio del gráfico de donut
r = 1.5
# Calcular el ancho de cada anillo
w = r / n

# Crear colores a lo largo de un mapa de colores elegido
colors = [cm.terrain(i / n) for i in range(n)]

# Crear la figura y el eje
fig, ax = plt.subplots()
ax.axis("equal")

# Crear los anillos del gráfico de donut
for i in range(n):
    # Ocultar las etiquetas en los segmentos con textprops: alpha = 0 - transparente, alpha = 1 - visible
    innerring, _ = ax.pie([m - data[i], data[i]], radius=r - i * w, startangle=90, labels=["", labels[i]], labeldistance=1 - 1 / (1.5 * (n - i)), textprops={"alpha": 0}, colors=["white", colors[i]])
    plt.setp(innerring, width=w, edgecolor="white")

plt.legend()
plt.show()

# %%
# Scatterplot

# Biblioteca y conjunto de datos
import seaborn as sns
df = sns.load_dataset('iris')

# Utilizar la función regplot para hacer un gráfico de dispersión con regresión lineal
sns.regplot(x=df["sepal_length"], y=df["sepal_width"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(data=iris_df, x = "sepal_length", y="sepal_width")
plt.show()

# %%
# Venn
# Biblioteca
import matplotlib.pyplot as plt
import matplotlib_venn
from matplotlib_venn import venn2

# Utilizar la función venn2
venn2(subsets=(10, 5, 2), set_labels=('Group A', 'Group B'))
plt.show()

# %%
# Wordcloud

# importar las librerias de uso
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# crear una lista de palabras
text = "Wordclouds.com is a free online word cloud generator and tag cloud creator. Wordclouds.com works on your PC, Tablet or smartphone. Paste text, upload a document or open an URL to automatically generate a word- or tag cloud. Or enter individual words manually in the word list. Pick a shape, select colors and fonts and choose how to draw the words. Wordclouds.com can also generate clickable word clouds with links (image map). When you are satisfied with the result, save the image and share it online."

# Se crea el canvas para el wordcloud
wordcloud = WordCloud(width = 480, height = 480, margin=0).generate(text)

# mostrar el mapa de palabras
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()

# %% [markdown]
# ## Tarea

# %% [markdown]
# ### Pandas

# %%
import pandas as pd
df = pd.read_csv('data/08.-temporal.csv')
df.head(10) #View first 10 data rows
# Out:
#           Mes  data science  machine learning  deep learning  categorical
# 0  2004-01-01            12                18              4            1
# 1  2004-02-01            12                21              2            1
# 2  2004-03-01             9                21              2            1
# 3  2004-04-01            10                16              4            1
# 4  2004-05-01             7                14              3            1
# 5  2004-06-01             9                17              3            1
# 6  2004-07-01             9                16              3            1
# 7  2004-08-01             7                14              3            1
# 8  2004-09-01            10                17              4            1
# 9  2004-10-01             8                17              4            1

# %%
df.describe()
# Out:
#        data science  machine learning  deep learning  categorical
# count    194.000000        194.000000     194.000000   194.000000
# mean      20.953608         27.396907      24.231959     0.257732
# std       23.951006         28.091490      34.476887     0.438517
# min        4.000000          7.000000       1.000000     0.000000
# 25%        6.000000          9.000000       2.000000     0.000000
# 50%        8.000000         13.000000       3.000000     0.000000
# 75%       26.750000         31.500000      34.000000     1.000000
# max      100.000000        100.000000     100.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Mes               194 non-null    object
#  1   data science      194 non-null    int64
#  2   machine learning  194 non-null    int64
#  3   deep learning     194 non-null    int64
#  4   categorical       194 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.7+ KB

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
df
# Out:
#             Mes  data science  machine learning  deep learning  categorical
# 0    2004-01-01            12                18              4            1
# 1    2004-02-01            12                21              2            1
# 2    2004-03-01             9                21              2            1
# 3    2004-04-01            10                16              4            1
# 4    2004-05-01             7                14              3            1
# 5    2004-06-01             9                17              3            1
# 6    2004-07-01             9                16              3            1
# 7    2004-08-01             7                14              3            1
# 8    2004-09-01            10                17              4            1
# 9    2004-10-01             8                17              4            1
# 10   2004-11-01             8                15              2            1
# 11   2004-12-01             8                16              2            1
# 12   2005-01-01            10                16              2            0
# 13   2005-02-01             9                14              3            0
# 14   2005-03-01             8                13              2            0
# 15   2005-04-01             8                12              3            0
# 16   2005-05-01             8                15              3            0
# 17   2005-06-01             8                12              3            0
# 18   2005-07-01             6                11              2            0
# 19   2005-08-01             9                10              2            0
# 20   2005-09-01             7                14              2            0
# 21   2005-10-01             7                16              3            0
# 22   2005-11-01             7                13              4            0
# 23   2005-12-01             5                13              2            0
# 24   2006-01-01             7                12              3            0
# 25   2006-02-01             7                12              3            0
# 26   2006-03-01             7                12              2            0
# 27   2006-04-01             7                12              2            0
# 28   2006-05-01             7                11              2            0
# 29   2006-06-01             6                10              2            0
# 30   2006-07-01             5                 9              1            0
# 31   2006-08-01             6                 9              2            0
# 32   2006-09-01             7                11              1            0
# 33   2006-10-01             6                11              2            0
# 34   2006-11-01             7                11              2            0
# 35   2006-12-01             4                 9              3            0
# 36   2007-01-01             6                11              2            0
# 37   2007-02-01             7                11              3            0
# 38   2007-03-01             6                 9              3            0
# 39   2007-04-01             5                10              3            0
# 40   2007-05-01             6                 9              1            0
# 41   2007-06-01             6                 9              2            0
# 42   2007-07-01             4                 9              2            0
# 43   2007-08-01             5                 9              3            0
# 44   2007-09-01             6                 9              2            0
# 45   2007-10-01             6                11              2            0
# 46   2007-11-01             6                10              2            0
# 47   2007-12-01             5                 8              3            0
# 48   2008-01-01             6                 9              2            1
# 49   2008-02-01             6                 9              2            1
# 50   2008-03-01             5                 8              3            1
# 51   2008-04-01             6                10              2            1
# 52   2008-05-01             5                 9              2            1
# 53   2008-06-01             5                 8              2            1
# 54   2008-07-01             5                 7              3            1
# 55   2008-08-01             5                 7              1            1
# 56   2008-09-01             6                 9              2            1
# 57   2008-10-01             6                10              2            1
# 58   2008-11-01             6                 9              2            1
# 59   2008-12-01             5                 8              2            1
# 60   2009-01-01             6                 8              3            0
# 61   2009-02-01             6                 9              3            0
# 62   2009-03-01             6                 8              2            0
# 63   2009-04-01             6                 9              3            0
# 64   2009-05-01             5                 8              2            0
# 65   2009-06-01             5                 8              2            0
# 66   2009-07-01             4                 8              2            0
# 67   2009-08-01             5                 8              2            0
# 68   2009-09-01             7                 8              3            0
# 69   2009-10-01             6                 9              2            0
# 70   2009-11-01             7                 9              2            0
# 71   2009-12-01             6                 8              2            0
# 72   2010-01-01             7                 8              2            0
# 73   2010-02-01             7                 9              2            0
# 74   2010-03-01             6                 9              2            0
# 75   2010-04-01             6                 9              2            0
# 76   2010-05-01             6                 8              2            0
# 77   2010-06-01             5                 8              2            0
# 78   2010-07-01             5                 8              3            0
# 79   2010-08-01             5                 8              2            0
# 80   2010-09-01             7                 9              2            0
# 81   2010-10-01             6                 9              3            0
# 82   2010-11-01             6                 9              3            0
# 83   2010-12-01             5                 9              2            0
# 84   2011-01-01             7                 8              3            0
# 85   2011-02-01             6                 9              2            0
# 86   2011-03-01             6                 9              3            0
# 87   2011-04-01             6                 9              2            0
# 88   2011-05-01             5                 9              3            0
# 89   2011-06-01             5                 8              2            0
# 90   2011-07-01             4                 7              2            0
# 91   2011-08-01             5                 8              2            0
# 92   2011-09-01             7                11              3            0
# 93   2011-10-01             7                12              3            0
# 94   2011-11-01             7                12              3            0
# 95   2011-12-01             6                10              2            0
# 96   2012-01-01             7                10              3            1
# 97   2012-02-01             7                11              3            1
# 98   2012-03-01             7                11              2            1
# 99   2012-04-01             6                11              3            1
# 100  2012-05-01             6                11              4            1
# 101  2012-06-01             6                10              3            1
# 102  2012-07-01             6                10              3            1
# 103  2012-08-01             7                10              3            1
# 104  2012-09-01            10                12              3            1
# 105  2012-10-01             8                13              4            1
# 106  2012-11-01             8                12              6            1
# 107  2012-12-01             6                11              4            1
# 108  2013-01-01             8                11              5            0
# 109  2013-02-01             8                12              4            0
# 110  2013-03-01             8                12              5            0
# 111  2013-04-01             9                13              6            0
# 112  2013-05-01             9                13              7            0
# 113  2013-06-01             8                12              5            0
# 114  2013-07-01             8                12              6            0
# 115  2013-08-01             9                11              6            0
# 116  2013-09-01            12                13              8            0
# 117  2013-10-01            11                16              7            0
# 118  2013-11-01            11                15              8            0
# 119  2013-12-01            10                14              8            0
# 120  2014-01-01            13                14              9            0
# 121  2014-02-01            12                16             10            0
# 122  2014-03-01            13                16             10            0
# 123  2014-04-01            13                17             10            0
# 124  2014-05-01            12                16             11            0
# 125  2014-06-01            12                15             10            0
# 126  2014-07-01            13                16              9            0
# 127  2014-08-01            16                16             11            0
# 128  2014-09-01            19                18             12            0
# 129  2014-10-01            17                18             12            0
# 130  2014-11-01            17                20             11            0
# 131  2014-12-01            16                18             17            0
# 132  2015-01-01            19                20             19            0
# 133  2015-02-01            18                21             20            0
# 134  2015-03-01            18                21             21            0
# 135  2015-04-01            20                24             19            0
# 136  2015-05-01            19                22             20            0
# 137  2015-06-01            20                24             23            0
# 138  2015-07-01            20                24             23            0
# 139  2015-08-01            23                23             22            0
# 140  2015-09-01            27                26             24            0
# 141  2015-10-01            25                27             24            0
# 142  2015-11-01            24                30             28            0
# 143  2015-12-01            22                28             28            0
# 144  2016-01-01            27                28             34            1
# 145  2016-02-01            27                32             34            1
# 146  2016-03-01            26                34             44            1
# 147  2016-04-01            27                34             44            1
# 148  2016-05-01            27                34             42            1
# 149  2016-06-01            27                36             46            1
# 150  2016-07-01            26                32             40            1
# 151  2016-08-01            29                34             41            1
# 152  2016-09-01            36                39             46            1
# 153  2016-10-01            33                42             52            1
# 154  2016-11-01            34                46             55            1
# 155  2016-12-01            33                46             59            1
# 156  2017-01-01            41                51             65            0
# 157  2017-02-01            42                56             69            0
# 158  2017-03-01            44                59             75            0
# 159  2017-04-01            42                61             76            0
# 160  2017-05-01            43                63             80            0
# 161  2017-06-01            43                65             78            0
# 162  2017-07-01            42                62             76            0
# 163  2017-08-01            47                64             84            0
# 164  2017-09-01            53                71             87            0
# 165  2017-10-01            53                75             89            0
# 166  2017-11-01            52                80             94            0
# 167  2017-12-01            48                72             91            0
# 168  2018-01-01            58                76             91            0
# 169  2018-02-01            57                80             93            0
# 170  2018-03-01            58                82             95            0
# 171  2018-04-01            58                82             95            0
# 172  2018-05-01            59                83             98            0
# 173  2018-06-01            57                81             90            0
# 174  2018-07-01            60                81             88            0
# 175  2018-08-01            64                82             87            0
# 176  2018-09-01            68                85             94            0
# 177  2018-10-01            70                90             97            0
# 178  2018-11-01            67                88             94            0
# 179  2018-12-01            61                81             87            0
# 180  2019-01-01            76                86             93            0
# 181  2019-02-01            77                93             95            0
# 182  2019-03-01            75                91             98            0
# 183  2019-04-01            77                92             98            0
# 184  2019-05-01            76                92             97            0
# 185  2019-06-01            80                93             96            0
# 186  2019-07-01            85                92             96            0
# 187  2019-08-01            88                93             92            0
# 188  2019-09-01            95               100            100            0
# 189  2019-10-01            90                98             98            0
# 190  2019-11-01            87                97             96            0
# 191  2019-12-01            81                89             91            0
# 192  2020-01-01            94                94             93            1
# 193  2020-02-01           100                99             99            1

# %%
format_dict = {'data science':'${0:,.2f}', 'Mes':'{:%m-%Y}', 'machine learning':'{:.2%}'}

#We make sure that the Month column has datetime format
df['Mes'] = pd.to_datetime(df['Mes'])

#We apply the style to the visualization
df.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_31f13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31f13_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_31f13_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_31f13_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_31f13_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_31f13_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31f13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31f13_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_31f13_row0_col1" class="data row0 col1" >$12.00</td>
#       <td id="T_31f13_row0_col2" class="data row0 col2" >1800.00%</td>
#       <td id="T_31f13_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_31f13_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_31f13_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31f13_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_31f13_row1_col1" class="data row1 col1" >$12.00</td>
#       <td id="T_31f13_row1_col2" class="data row1 col2" >2100.00%</td>
#       <td id="T_31f13_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_31f13_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_31f13_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31f13_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_31f13_row2_col1" class="data row2 col1" >$9.00</td>
#       <td id="T_31f13_row2_col2" class="data row2 col2" >2100.00%</td>
#       <td id="T_31f13_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_31f13_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_31f13_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31f13_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_31f13_row3_col1" class="data row3 col1" >$10.00</td>
#       <td id="T_31f13_row3_col2" class="data row3 col2" >1600.00%</td>
#       <td id="T_31f13_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_31f13_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_31f13_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_31f13_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_31f13_row4_col1" class="data row4 col1" >$7.00</td>
#       <td id="T_31f13_row4_col2" class="data row4 col2" >1400.00%</td>
#       <td id="T_31f13_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_31f13_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
format_dict = {'Mes':'{:%m-%Y}'} #Simplified format dictionary with values that do make sense for our data
df.head().style.format(format_dict).highlight_max(color='darkgreen').highlight_min(color='#ff0000')
# Out:
# <style type="text/css">
# #T_63eb6_row0_col0, #T_63eb6_row1_col3, #T_63eb6_row2_col3, #T_63eb6_row4_col1, #T_63eb6_row4_col2 {
#   background-color: #ff0000;
# }
# #T_63eb6_row0_col1, #T_63eb6_row0_col3, #T_63eb6_row1_col1, #T_63eb6_row1_col2, #T_63eb6_row2_col2, #T_63eb6_row3_col3, #T_63eb6_row4_col0 {
#   background-color: darkgreen;
# }
# #T_63eb6_row0_col4, #T_63eb6_row1_col4, #T_63eb6_row2_col4, #T_63eb6_row3_col4, #T_63eb6_row4_col4 {
#   background-color: darkgreen;
#   background-color: #ff0000;
# }
# </style>
# <table id="T_63eb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63eb6_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_63eb6_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_63eb6_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_63eb6_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_63eb6_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63eb6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63eb6_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_63eb6_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_63eb6_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_63eb6_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_63eb6_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63eb6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63eb6_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_63eb6_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_63eb6_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_63eb6_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_63eb6_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63eb6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63eb6_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_63eb6_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_63eb6_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_63eb6_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_63eb6_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63eb6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63eb6_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_63eb6_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_63eb6_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_63eb6_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_63eb6_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63eb6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63eb6_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_63eb6_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_63eb6_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_63eb6_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_63eb6_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn')
# Out:
# <style type="text/css">
# #T_8037b_row0_col1, #T_8037b_row1_col1, #T_8037b_row1_col2, #T_8037b_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_8037b_row0_col2 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_8037b_row2_col1, #T_8037b_row5_col1, #T_8037b_row6_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_8037b_row3_col1, #T_8037b_row8_col1 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_8037b_row3_col2, #T_8037b_row6_col2 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_8037b_row4_col1, #T_8037b_row4_col2, #T_8037b_row7_col1, #T_8037b_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_8037b_row5_col2, #T_8037b_row8_col2, #T_8037b_row9_col2 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_8037b_row9_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_8037b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8037b_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_8037b_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_8037b_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_8037b_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_8037b_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8037b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8037b_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_8037b_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_8037b_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_8037b_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_8037b_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8037b_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_8037b_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_8037b_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_8037b_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_8037b_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8037b_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_8037b_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_8037b_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_8037b_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_8037b_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8037b_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_8037b_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_8037b_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_8037b_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_8037b_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8037b_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_8037b_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_8037b_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_8037b_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_8037b_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8037b_row5_col0" class="data row5 col0" >06-2004</td>
#       <td id="T_8037b_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_8037b_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_8037b_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_8037b_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8037b_row6_col0" class="data row6 col0" >07-2004</td>
#       <td id="T_8037b_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_8037b_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_8037b_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_8037b_row6_col4" class="data row6 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8037b_row7_col0" class="data row7 col0" >08-2004</td>
#       <td id="T_8037b_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_8037b_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_8037b_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_8037b_row7_col4" class="data row7 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8037b_row8_col0" class="data row8 col0" >09-2004</td>
#       <td id="T_8037b_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_8037b_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_8037b_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_8037b_row8_col4" class="data row8 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8037b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8037b_row9_col0" class="data row9 col0" >10-2004</td>
#       <td id="T_8037b_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_8037b_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_8037b_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_8037b_row9_col4" class="data row9 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head().style.format(format_dict).bar(color='red', subset=['data science', 'deep learning'])
# Out:
# <style type="text/css">
# #T_7b519_row0_col1, #T_7b519_row0_col3, #T_7b519_row1_col1, #T_7b519_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# #T_7b519_row1_col3, #T_7b519_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, red 50.0%, transparent 50.0%);
# }
# #T_7b519_row2_col1, #T_7b519_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, red 75.0%, transparent 75.0%);
# }
# #T_7b519_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, red 83.3%, transparent 83.3%);
# }
# #T_7b519_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, red 58.3%, transparent 58.3%);
# }
# </style>
# <table id="T_7b519">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b519_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_7b519_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_7b519_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_7b519_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_7b519_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b519_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b519_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_7b519_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_7b519_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_7b519_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_7b519_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b519_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b519_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_7b519_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_7b519_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_7b519_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_7b519_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b519_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b519_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_7b519_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_7b519_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_7b519_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_7b519_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b519_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b519_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_7b519_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_7b519_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_7b519_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_7b519_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7b519_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b519_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_7b519_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_7b519_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_7b519_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_7b519_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn').highlight_max(color='yellow')
# Out:
# <style type="text/css">
# #T_e8236_row0_col1, #T_e8236_row1_col1, #T_e8236_row1_col2, #T_e8236_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: yellow;
# }
# #T_e8236_row0_col2 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_e8236_row0_col3, #T_e8236_row0_col4, #T_e8236_row1_col4, #T_e8236_row2_col4, #T_e8236_row3_col3, #T_e8236_row3_col4, #T_e8236_row4_col4, #T_e8236_row5_col4, #T_e8236_row6_col4, #T_e8236_row7_col4, #T_e8236_row8_col3, #T_e8236_row8_col4, #T_e8236_row9_col0, #T_e8236_row9_col3, #T_e8236_row9_col4 {
#   background-color: yellow;
# }
# #T_e8236_row2_col1, #T_e8236_row5_col1, #T_e8236_row6_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_e8236_row3_col1, #T_e8236_row8_col1 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_e8236_row3_col2, #T_e8236_row6_col2 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_e8236_row4_col1, #T_e8236_row4_col2, #T_e8236_row7_col1, #T_e8236_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_e8236_row5_col2, #T_e8236_row8_col2, #T_e8236_row9_col2 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_e8236_row9_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_e8236">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8236_level0_col0" class="col_heading level0 col0" >Mes</th>
#       <th id="T_e8236_level0_col1" class="col_heading level0 col1" >data science</th>
#       <th id="T_e8236_level0_col2" class="col_heading level0 col2" >machine learning</th>
#       <th id="T_e8236_level0_col3" class="col_heading level0 col3" >deep learning</th>
#       <th id="T_e8236_level0_col4" class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8236_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8236_row0_col0" class="data row0 col0" >01-2004</td>
#       <td id="T_e8236_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_e8236_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_e8236_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_e8236_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8236_row1_col0" class="data row1 col0" >02-2004</td>
#       <td id="T_e8236_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_e8236_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_e8236_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_e8236_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8236_row2_col0" class="data row2 col0" >03-2004</td>
#       <td id="T_e8236_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_e8236_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_e8236_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_e8236_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8236_row3_col0" class="data row3 col0" >04-2004</td>
#       <td id="T_e8236_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_e8236_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_e8236_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_e8236_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8236_row4_col0" class="data row4 col0" >05-2004</td>
#       <td id="T_e8236_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_e8236_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_e8236_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_e8236_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8236_row5_col0" class="data row5 col0" >06-2004</td>
#       <td id="T_e8236_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_e8236_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_e8236_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_e8236_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8236_row6_col0" class="data row6 col0" >07-2004</td>
#       <td id="T_e8236_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_e8236_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_e8236_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_e8236_row6_col4" class="data row6 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8236_row7_col0" class="data row7 col0" >08-2004</td>
#       <td id="T_e8236_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_e8236_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_e8236_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_e8236_row7_col4" class="data row7 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8236_row8_col0" class="data row8 col0" >09-2004</td>
#       <td id="T_e8236_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_e8236_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_e8236_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_e8236_row8_col4" class="data row8 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8236_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8236_row9_col0" class="data row9 col0" >10-2004</td>
#       <td id="T_e8236_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_e8236_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_e8236_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_e8236_row9_col4" class="data row9 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot(df['Mes'], df['data science'], label='data science') #The parameter label is to indicate the legend. This doesn't mean that it will be shown, we'll have to use another command that I'll explain later.

# %%
plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')

# %%
plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()

# %%
fig, axes = plt.subplots(2,2)
axes[0, 0].hist(df['data science'])
axes[0, 1].scatter(df['Mes'], df['data science'])
axes[1, 0].plot(df['Mes'], df['machine learning'])
axes[1, 1].plot(df['Mes'], df['deep learning'])

# %%
plt.plot(df['Mes'], df['data science'], 'r-')
plt.plot(df['Mes'], df['data science']*2, 'bs')
plt.plot(df['Mes'], df['data science']*3, 'g^')

# %%
plt.scatter(df['data science'], df['machine learning'])

# %%
plt.bar(df['Mes'], df['machine learning'], width=20)
# Out:
# <BarContainer object of 194 artists>

# %%
plt.hist(df['deep learning'], bins=15)
# Out:
# (array([117.,  14.,   5.,   6.,   2.,   3.,   6.,   1.,   2.,   1.,   1.,
#           5.,   1.,  13.,  17.]),
#  array([  1. ,   7.6,  14.2,  20.8,  27.4,  34. ,  40.6,  47.2,  53.8,
#          60.4,  67. ,  73.6,  80.2,  86.8,  93.4, 100. ]),
#  <BarContainer object of 15 artists>)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Cargar los datos desde el archivo 'temporal.csv'
df = pd.read_csv('data/08.-temporal.csv')

# Graficar las líneas de cada columna
plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')

plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)

# Agregar texto y anotación al gráfico
plt.text(0, 80, r'$\lambda=1, r^2=0.8$')
plt.annotate('Notice something?', xy=('2014-01-01', 30), xytext=('2006-01-01', 50), arrowprops={'facecolor':'red', 'shrink':0.05})

# Mostrar el gráfico
plt.legend()
plt.show()

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

sns.set()
sns.scatterplot(x='Mes', y='data science', data=df)
# Out:
# <Axes: xlabel='Mes', ylabel='data science'>

# %%
sns.relplot(x='Mes', y='deep learning', hue='data science', size='machine learning', col='categorical', data=df)
# Out:
# d:\Projects\VSCode\ciencia_datos\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
# Seleccionar solo las columnas numéricas para la matriz de correlación
num_cols = ['data science', 'machine learning', 'deep learning']

# Convertir las columnas numéricas a valores numéricos si es necesario
for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Obtener la matriz de correlación solo para las columnas numéricas
correlation_matrix = df[num_cols].corr()

# Generar el heatmap
sns.heatmap(correlation_matrix, annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# d:\Projects\VSCode\ciencia_datos\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
sns.pairplot(df, hue='categorical')
# Out:
# d:\Projects\VSCode\ciencia_datos\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
sns.jointplot(x='data science', y='machine learning', data=df)

# %%
sns.catplot(x='categorical', y='data science', kind='violin', data=df)
# Out:
# d:\Projects\VSCode\ciencia_datos\.venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(8, 4))
sns.scatterplot(x="Mes", y="deep learning", hue="categorical", data=df, ax=axes[0])
axes[0].set_title('Deep Learning')
sns.scatterplot(x="Mes", y="machine learning", hue="categorical", data=df, ax=axes[1])
axes[1].set_title('Machine Learning')
# Out:
# Text(0.5, 1.0, 'Machine Learning')

# %% [markdown]
# ### Folium

# %%
import folium
m1 = folium.Map(location=[41.38, 2.17], tiles='openstreetmap', zoom_start=18)
m1.save('map1.html')

# %%
m2 = folium.Map(location=[41.38, 2.17], tiles='openstreetmap', zoom_start=16)

folium.Marker([41.38, 2.176], popup='<i>You can use whatever HTML code you want</i>', tooltip='click here').add_to(m2)
folium.Marker([41.38, 2.174], popup='<b>You can use whatever HTML code you want</b>', tooltip='dont click here').add_to(m2)

m2.save('map2.html')
